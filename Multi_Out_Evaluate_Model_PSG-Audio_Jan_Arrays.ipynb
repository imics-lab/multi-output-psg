# %% [markdown]
# #Multiple Output [Cardiac, Respiratory] Evaluate Model PSG-Audio
#
# This version forked from Cardiac equivalent 2/10/2023.   Results from cardiac alone are still challenging.
#
# Author:  [Lee B. Hinkle](https://userweb.cs.txstate.edu/~lbh31/), [IMICS Lab](https://imics.wp.txstate.edu/), Texas State University, 2023
#
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
#
# TODO:
#
# * Tuning and general model improvements, the inputs currently are not sample weighted.

# %% [markdown]
# # Imports

# %%
import os
import shutil
import time
from datetime import datetime
from datetime import date
from datetime import timedelta # for calculating training time
from random import randrange # for plotting samples
import numpy as np
import matplotlib.pyplot as plt # for plotting training curves
from tabulate import tabulate # for verbose tables, showing data
import tensorflow as tf
from tensorflow import keras #added to save model
from tensorflow.keras import layers #format matches MNIST example
from tensorflow.keras.callbacks import EarlyStopping
#imports for computing and displaying output metrics
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import compute_sample_weight
import sys
import urllib.request # to get files from web w/o !wget
from shutil import unpack_archive # to unzip

# %%
interactive = True # this is an interactive notebook, keeping this for compatibility

# %% [markdown]
# # Get small or full processed PSG-Audio numpy arrays
# See PSG-Audio_load_dataset_for_multi-output.ipynb for info, this is source of the arrays.

# %%
use_small = True # arrays are 1/10th the size for shorter download/train time
# From readme
# PSG-Audio data subs at 3s window and 3s step.
# Saved to /content/drive/MyDrive/Processed_Datasets/PSG-Audio/PSG_12ch_90_10_3s_3s
# Generated by PSG-Audio_load_dataset_for_multi-output.ipynb on Jan-31-2023_1956
# this version for multi-outout cardio/respiratory work
# contains data 9 200Hz channels downsample to 100Hz and
# One in five subs allocated to test.
# balance of subs in train, intent is to use groupkfold
# along with the sub array that is also saved
# this version discards extremely rare events in train
# and also collapses remaining cardio to normal(0), abnormal(1)
# and puts all resp:apnea into a single event(1) along with
# keeping hyponea.  So resp: normal, apnea, hyponea
working_dir = "." # just to stay compatible, gdown uses current dir.
if use_small:
    version = "small"
    print("Downloading small arrays")
    flist = ["small_x_train.npy", "small_y_train.npy", "small_sub_train.npy"]
    # !gdown "1zo_Amyb_vbAL1VKpa1IKtuHpL5Gw9IaG&confirm=t" # small_x_train
    # !gdown "1_ZFknIBTNaCS7lCILDM0loUOFUUzz8EZ&confirm=t" # small_y_train
    # !gdown "1KbOqMdPlOUaT1TQMY_NTp-oKqnRzelfb&confirm=t" # small_sub_train

    X = np.load(os.path.join(working_dir, 'small_x_train.npy'))
    y = np.load(os.path.join(working_dir, 'small_y_train.npy'))
    sub = np.load(os.path.join(working_dir, 'small_sub_train.npy'))
else:
    version = "full"
    print("Downloading full arrays - will require a high-RAM runtime")
    flist = ["x_train.npy", "y_train.npy", "sub_train.npy"]
    # !gdown "1-trnx46IB9oFaTeSIbCNL4XxJq4gifsh&confirm=t" # x_train
    # !gdown "105A0smVAjmJ_bEOuAAbHsHRR79PawcBm&confirm=t" # y_train
    # !gdown "1-w2Kpzg48MNUv1t82Zfn_p2axllcn-rJ&confirm=t" # sub_train

    X = np.load(os.path.join(working_dir, 'x_train.npy'))
    y = np.load(os.path.join(working_dir, 'y_train.npy'))
    sub = np.load(os.path.join(working_dir, 'sub_train.npy'))   

headers = ("Array","shape", "data type")
mydata = [("X:", X.shape, X.dtype),
        ("y:", y.shape, y.dtype),
        ("sub:", sub.shape, sub.dtype)]
print("\n",tabulate(mydata, headers=headers))
# Out:
# Downloading small arrays
# Downloading...
# From: https://drive.google.com/uc?id=1zo_Amyb_vbAL1VKpa1IKtuHpL5Gw9IaG&confirm=t
# To: /content/small_x_train.npy
# 100% 610M/610M [00:08<00:00, 69.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_ZFknIBTNaCS7lCILDM0loUOFUUzz8EZ&confirm=t
# To: /content/small_y_train.npy
# 100% 84.8k/84.8k [00:00<00:00, 61.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KbOqMdPlOUaT1TQMY_NTp-oKqnRzelfb&confirm=t
# To: /content/small_sub_train.npy
# 100% 84.8k/84.8k [00:00<00:00, 73.8MB/s]
#
#  Array    shape             data type
# -------  ----------------  -----------
# X:       (42333, 300, 12)  float32
# y:       (42333, 2)        int8
# sub:     (42333, 1)        uint16

# %% [markdown]
# # Build Dictionaries with X split by Signal Modality and y by Event Type

# %%
# Building a dictionary with keys equaling the modality of the signals
# There may be some benefit to additional preprocessing in the model itself.
# https://keras.io/guides/preprocessing_layers/

X_eeg = X[:,:,0:3] # first 3 channels (0,1,2)
X_eog = X[:,:,3:5] # channels 3 and 4
X_emg = X[:,:,5:6] # just channel 5, for one channel this syntax keeps the shape
X_ecg = X[:,:,8:9] # ECG
X_flow = X[:,:,9:10] # nasal cannula
X_reff = X[:,:,10:12] # abd, thor respiratory effort via RIP bands

y_card = y[:,0:1] # cardiac events are first column of y
y_resp = y[:,1:2] # respiratory events are second column of y

X_all = [X_eeg, X_eog, X_emg, X_ecg, X_flow, X_reff]
X_all_dict = {'eeg': X_eeg, 'eog':X_eog, 'emg':X_emg, 'ecg':X_ecg, 'flow':X_flow, 'reff':X_reff}
y_all = [y_card, y_resp]
y_all_dict = {'card':y_card,'resp':y_resp}
for key,item in X_all_dict.items():
    print(key,item.shape)
for key, item in y_all_dict.items():
    print(key,item.shape)
    
# for this version of the dataset, normal instances were dropped to balance
# respiratory, leaving cardiac still imbalanced.
# All not normal cardiac events were collapsed into a single abnormal label
# For respiratory the various apneas were collapsed so apnea and hypopnea remain
unique, counts = np.unique(y_card, return_counts=True)
print("\ny_card label values and counts:\n",str(np.asarray((unique, counts)).T))
class_names_y_card = ['Normal','Abnormal'] # matches _90_10 processed files

unique, counts = np.unique(y_resp, return_counts=True)
print("\ny_resp label values and counts:\n",str(np.asarray((unique, counts)).T))
class_names_y_resp = ['Normal','Apnea','Hypopnea'] # matches _90_10 processed files
# Out:
# eeg (42333, 300, 3)
# eog (42333, 300, 2)
# emg (42333, 300, 1)
# ecg (42333, 300, 1)
# flow (42333, 300, 1)
# reff (42333, 300, 2)
# card (42333, 1)
# resp (42333, 1)
#
# y_card label values and counts:
#  [[    0 37157]
#  [    1  5176]]
#
# y_resp label values and counts:
#  [[    0 23252]
#  [    1 15479]
#  [    2  3602]]

# %%
# topology and good article here
# https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf
# ref for functional model https://keras.io/guides/functional_api/

def build_model(X_all_dict,y_all_dict):

    # input layers - 1st dim is timesteps, 2nd is features
    # this method give some configurability but lacks error checking.
    eeg_input = keras.Input(shape = (X_all_dict['eeg'].shape[1], X_all_dict['eeg'].shape[2]), name = "eeg")
    eog_input = keras.Input(shape = (X_all_dict['eog'].shape[1], X_all_dict['eog'].shape[2]), name = "eog")
    emg_input = keras.Input(shape = (X_all_dict['emg'].shape[1], X_all_dict['emg'].shape[2]), name = "emg")
    ecg_input = keras.Input(shape = (X_all_dict['ecg'].shape[1], X_all_dict['ecg'].shape[2]), name = "ecg")
    flow_input = keras.Input(shape = (X_all_dict['flow'].shape[1], X_all_dict['flow'].shape[2]), name = "flow")
    reff_input = keras.Input(shape = (X_all_dict['reff'].shape[1], X_all_dict['reff'].shape[2]), name = "reff")

    a = layers.Conv1D(filters=50, kernel_size=17, activation='relu')(eog_input)
    #https://www.tensorflow.org/api_docs/python/tf/keras/layers/SpatialDropout1D
    #SpatialDropout1D will help promote independence between feature maps [in early conv layers]"
    a = layers.SpatialDropout1D(0.25)(a)
    a = layers.Conv1D(filters=50, kernel_size=17, activation='relu')(a)
    a = layers.MaxPooling1D(pool_size=12)(a)
    a = layers.Dropout(0.25)(a)

    b = layers.Conv1D(filters=50, kernel_size=67, activation='relu')(ecg_input)
    b = layers.SpatialDropout1D(0.25)(b)
    b = layers.Conv1D(filters=50, kernel_size=33, activation='relu')(b)
    b = layers.MaxPooling1D(pool_size=12)(b)
    b = layers.Dropout(0.25)(b)

    c = layers.Conv1D(filters=50, kernel_size=17, activation='relu')(flow_input)
    c = layers.SpatialDropout1D(0.25)(c)
    c = layers.Conv1D(filters=50, kernel_size=17, activation='relu')(c)
    c = layers.MaxPooling1D(pool_size=12)(c)
    c = layers.Dropout(0.25)(c)

    d = layers.Conv1D(filters=50, kernel_size=33, activation='relu')(reff_input)
    d = layers.SpatialDropout1D(0.25)(d)
    d = layers.Conv1D(filters=50, kernel_size=33, activation='relu')(d)
    d = layers.MaxPooling1D(pool_size=12)(d)
    d = layers.Dropout(0.25)(d)

    #merged = layers.Concatenate(axis=1)([c, d]) 
    #merged = layers.GlobalAveragePooling1D()(merged)
    
    a = layers.Flatten()(a) # must pass tensor not as arg
    b = layers.Flatten()(b)
    c = layers.Flatten()(c)
    d = layers.Flatten()(d)

    merged = layers.Concatenate(axis=-1)([a,b,c,d])
    merged = layers.Dense(100, activation='relu')(merged)
    #merged = layers.Dropout(0.25)(merged)
    merged = layers.Dense(50, activation='relu')(merged)
    
    #n_outputs = y_resp.shape[1] 
    # this is going to be a pain between cardiac and resp until in model!
    card_pred = layers.Dense(2, activation='softmax', name='card_pred')(merged)

    resp_pred = layers.Dense(3, activation='softmax', name='resp_pred')(merged)

    model = keras.Model([eeg_input, eog_input, emg_input, ecg_input, flow_input, reff_input],
                        [card_pred, resp_pred])
    return model
if interactive:
    my_model = build_model(X_all_dict, y_all_dict)
    # model.summary()
    # pass rankdir="LR" to plot_model to display sideways
    display(keras.utils.plot_model(my_model, "my_model.png", show_shapes=True, rankdir = "LR"))

# %% [markdown]
# # Define function to train model

# %%
def train_model(model, X_train_dict, y_train_dict, 
                X_valid_dict, y_valid_dict,
                BATCH_SIZE = 256, # Larger batch sizes smooth loss curves
                NUM_EPOCHS = 50): # Max number run unless earlystopping callback fires

    callback = EarlyStopping(monitor='val_loss', mode = 'min', patience=10)
    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

    # Despite some old examples online class weights cannot be used for multi-output models
    # class_weight={'card_pred':[1,10],'resp_pred':[1,2,10]} # just an educated guess...
    # class_weight={'card_pred':{0:1,1:10},'resp_pred':{0:1,1:2,3:10}} # just an educated guess...
    # class_weight={0: 1, 1: 10}
    # class_weight = [{0: 1, 1: 10},{0: 1, 1: 1, 2: 10}]

    sample_weights = {}
    sw_card = compute_sample_weight('balanced', y_train_dict['card'])
    sw_card = np.sqrt(sw_card) # no idea why weights are squared.
    sw_card = np.power(sw_card, 0.7) # to allow for tuning
    sample_weights['card_pred'] = sw_card

    sw_resp = compute_sample_weight('balanced', y_train_dict['resp'])
    sw_resp = np.sqrt(sw_resp) # no idea why weights are squared.
    sw_resp = np.power(sw_resp, 0.7) # to allow for tuning
    sample_weights['resp_pred'] = sw_resp
    # print("sample_weights",sample_weights) # this is a really long vector
    #unique, counts = np.unique(sample_weights, return_counts=True)
    #print("sample_weights values and counts:\n",str(np.asarray((unique, counts)).T))
    
    history = model.fit(
        {"eeg": X_train_dict['eeg'], "eog": X_train_dict['eog'], "emg": X_train_dict['emg'],
         "ecg": X_train_dict['ecg'], "flow": X_train_dict['flow'], "reff":X_train_dict['reff']},
         {"card_pred":y_train_dict['card'], "resp_pred":y_train_dict['resp']},
        batch_size = BATCH_SIZE,
        epochs=NUM_EPOCHS,
        callbacks=[callback],
        sample_weight=sample_weights,
        validation_data=({"eeg": X_valid_dict['eeg'], "eog": X_valid_dict['eog'], 
                          "emg": X_valid_dict['emg'], "ecg": X_valid_dict['ecg'],
                          "flow": X_valid_dict['flow'], "reff":X_valid_dict['reff']},
                         {"card_pred": y_valid_dict['card'], "resp_pred":y_valid_dict['resp']}),             
        verbose = 1) #0 = silent, 1 = progress bar, 2 = one line per epoch
    return history, model

# %% [markdown]
# ## Run a stratified 5-fold group-based cross validation

# %%
# Define per-fold score containers
card_acc_per_fold = []
card_loss_per_fold = []
card_y_pred_per_fold = []
card_y_valid_per_fold = []
resp_acc_per_fold = []
resp_loss_per_fold = []
resp_y_pred_per_fold = []
resp_y_valid_per_fold = []

skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)

start_time = time.time()

for i, (train_index, valid_index) in enumerate(skf.split(X, y[:,0], groups=sub)):
        print(f"Fold {i}:")
        #print(len(train_index), train_index)
        #print(len(valid_index), valid_index)

        # More complicated with dictionary of multiple inputs.
        # iterate through all keys and add the proper index array

        X_train_dict = {}
        X_valid_dict = {}
        y_train_dict = {}
        y_valid_dict = {}

        for key,item in X_all_dict.items():
            X_train_dict[key] = item[train_index]
            X_valid_dict[key] = item[valid_index]
        for key,item in y_all_dict.items():
            y_train_dict[key] = item[train_index]
            y_valid_dict[key] = item[valid_index]
        
        # for key,item in X_train_dict.items():
        #     print(key,item.shape)
        # for key,item in y_train_dict.items():
        #     print(key,item.shape)
        # for key,item in X_valid_dict.items():
        #     print(key,item.shape)
        # for key,item in y_valid_dict.items():
        #     print(key,item.shape)

        # TODO:  Move one-hot into model
        enc = OneHotEncoder(handle_unknown = 'ignore', sparse_output=False)
        y_train_dict['card'] = enc.fit_transform(y_train_dict['card'])
        y_valid_dict['card'] = enc.transform(y_valid_dict['card'])

        y_train_dict['resp'] = enc.fit_transform(y_train_dict['resp'])
        y_valid_dict['resp'] = enc.transform(y_valid_dict['resp'])

        # print(y_train_resp.shape)
        # print(y_valid_resp.shape)

        my_model = build_model(X_train_dict, y_train_dict)
        history, model = train_model(my_model, X_train_dict, y_train_dict, X_valid_dict, y_valid_dict)

        if (i == 0):  # saving arrays and model for debugging
            np.save('X_valid_dict.npy', X_valid_dict)
            np.save('y_valid_dict.npy', y_valid_dict)
            #read_dictionary = np.load('my_file.npy',allow_pickle='TRUE').item()
            my_model.save('my_model')
            print(history.history.keys())
            #model = keras.models.load_model('path/to/location')

        val_card_acc = history.history['val_card_pred_accuracy'][-1]
        val_card_loss = history.history['val_card_pred_loss'][-1] 
        card_acc_per_fold.append(val_card_acc * 100)
        card_loss_per_fold.append(val_card_loss)

        val_resp_acc = history.history['val_resp_pred_accuracy'][-1]
        val_resp_loss = history.history['val_resp_pred_loss'][-1] 
        resp_acc_per_fold.append(val_resp_acc * 100)
        resp_loss_per_fold.append(val_resp_loss)
                
        # Generate predictions
        y_pred = model.predict(X_valid_dict)

        card_y_pred = np.argmax(y_pred[0], axis=1)
        card_y_pred_per_fold.append(card_y_pred)
        card_y_valid_per_fold.append(np.argmax(y_valid_dict['card'], axis=1))

        resp_y_pred = np.argmax(y_pred[1], axis=1)
        resp_y_pred_per_fold.append(resp_y_pred)
        resp_y_valid_per_fold.append(np.argmax(y_valid_dict['resp'], axis=1))

        # Plot training & validation loss values
        plt.plot(history.history['card_pred_loss'], label="Cardiac Training Loss")
        plt.plot(history.history['val_card_pred_loss'],label="Cardiac Validation Loss")
        plt.plot(history.history['resp_pred_loss'],label="Resp Training Loss")
        plt.plot(history.history['val_resp_pred_loss'],label="Resp Validation Loss")
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.ylim([0,1.5]) #set limit - 1.2 has been a good value experimentally
        plt.legend(loc='upper right')
        plt.show()

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(card_acc_per_fold)):
#     print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Card > Loss: {card_loss_per_fold[i]:4.2} - Accuracy: {card_acc_per_fold[i]:4.2f}%')
    print(f'> Fold {i+1} - Resp > Loss: {resp_loss_per_fold[i]:4.2} - Accuracy: {resp_acc_per_fold[i]:4.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Card Accuracy: {np.mean(card_acc_per_fold):4.2f} (+- {np.std(card_acc_per_fold):5.4})')
print(f'> Reso Accuracy: {np.mean(resp_acc_per_fold):4.2f} (+- {np.std(resp_acc_per_fold):5.4})')
card_acc_str = temp = str(f'> Card Accuracy: {np.mean(card_acc_per_fold):4.2f} (+- {np.std(card_acc_per_fold):5.4})')
resp_acc_str = temp = str(f'> Resp Accuracy: {np.mean(resp_acc_per_fold):4.2f} (+- {np.std(resp_acc_per_fold):5.4})')
print('------------------------------------------------------------------------')

# Show total training time
end_time = time.time()
train_time = timedelta(seconds=(end_time - start_time))
print('Total Training time =',(str(train_time).split(".")[0]), 'HH:MM:SS')
# to plot confusion matrices return concat versions of y
card_y_pred = np.concatenate(card_y_pred_per_fold)
card_y_valid = np.concatenate(card_y_valid_per_fold)
resp_y_pred = np.concatenate(resp_y_pred_per_fold)
resp_y_valid = np.concatenate(resp_y_valid_per_fold)
#return acc_str, y_pred, y_test
# Out:
# Fold 0:
# Epoch 1/50
# 136/136 [==============================] - 11s 51ms/step - loss: 2.5847 - card_pred_loss: 1.0398 - resp_pred_loss: 1.5450 - card_pred_accuracy: 0.7816 - resp_pred_accuracy: 0.6741 - val_loss: 1.3361 - val_card_pred_loss: 0.5797 - val_resp_pred_loss: 0.7564 - val_card_pred_accuracy: 0.8041 - val_resp_pred_accuracy: 0.6934
# Epoch 2/50
# 136/136 [==============================] - 7s 49ms/step - loss: 1.2577 - card_pred_loss: 0.5794 - resp_pred_loss: 0.6783 - card_pred_accuracy: 0.8362 - resp_pred_accuracy: 0.7538 - val_loss: 1.2876 - val_card_pred_loss: 0.5492 - val_resp_pred_loss: 0.7384 - val_card_pred_accuracy: 0.7756 - val_resp_pred_accuracy: 0.7068
# Epoch 3/50
# 136/136 [==============================] - 6s 47ms/step - loss: 1.2101 - card_pred_loss: 0.5705 - resp_pred_loss: 0.6397 - card_pred_accuracy: 0.8465 - resp_pred_accuracy: 0.7671 - val_loss: 1.2744 - val_card_pred_loss: 0.5380 - val_resp_pred_loss: 0.7365 - val_card_pred_accuracy: 0.7952 - val_resp_pred_accuracy: 0.7266
# Epoch 4/50
# 136/136 [==============================] - 6s 48ms/step - loss: 1.1674 - card_pred_loss: 0.5606 - resp_pred_loss: 0.6068 - card_pred_accuracy: 0.8473 - resp_pred_accuracy: 0.7796 - val_loss: 1.2945 - val_card_pred_loss: 0.5291 - val_resp_pred_loss: 0.7654 - val_card_pred_accuracy: 0.7909 - val_resp_pred_accuracy: 0.7228
# Epoch 5/50
# 136/136 [==============================] - 6s 47ms/step - loss: 1.1370 - card_pred_loss: 0.5468 - resp_pred_loss: 0.5903 - card_pred_accuracy: 0.8460 - resp_pred_accuracy: 0.7896 - val_loss: 1.2249 - val_card_pred_loss: 0.5243 - val_resp_pred_loss: 0.7005 - val_card_pred_accuracy: 0.7864 - val_resp_pred_accuracy: 0.7409
# Epoch 6/50
# 136/136 [==============================] - 7s 50ms/step - loss: 1.1008 - card_pred_loss: 0.5256 - resp_pred_loss: 0.5751 - card_pred_accuracy: 0.8344 - resp_pred_accuracy: 0.7927 - val_loss: 1.1997 - val_card_pred_loss: 0.4880 - val_resp_pred_loss: 0.7117 - val_card_pred_accuracy: 0.7970 - val_resp_pred_accuracy: 0.7358
# Epoch 7/50
# 136/136 [==============================] - 6s 47ms/step - loss: 1.0576 - card_pred_loss: 0.4985 - resp_pred_loss: 0.5591 - card_pred_accuracy: 0.8386 - resp_pred_accuracy: 0.7980 - val_loss: 1.1816 - val_card_pred_loss: 0.4805 - val_resp_pred_loss: 0.7010 - val_card_pred_accuracy: 0.7969 - val_resp_pred_accuracy: 0.7404
# Epoch 8/50
# 136/136 [==============================] - 6s 48ms/step - loss: 1.0290 - card_pred_loss: 0.4768 - resp_pred_loss: 0.5522 - card_pred_accuracy: 0.8467 - resp_pred_accuracy: 0.8000 - val_loss: 1.1840 - val_card_pred_loss: 0.5005 - val_resp_pred_loss: 0.6834 - val_card_pred_accuracy: 0.7659 - val_resp_pred_accuracy: 0.7431
# Epoch 9/50
# 136/136 [==============================] - 7s 48ms/step - loss: 1.0082 - card_pred_loss: 0.4662 - resp_pred_loss: 0.5420 - card_pred_accuracy: 0.8495 - resp_pred_accuracy: 0.8017 - val_loss: 1.2152 - val_card_pred_loss: 0.4895 - val_resp_pred_loss: 0.7257 - val_card_pred_accuracy: 0.7894 - val_resp_pred_accuracy: 0.7252
# Epoch 10/50
# 136/136 [==============================] - 6s 47ms/step - loss: 1.0007 - card_pred_loss: 0.4582 - resp_pred_loss: 0.5425 - card_pred_accuracy: 0.8558 - resp_pred_accuracy: 0.8008 - val_loss: 1.2053 - val_card_pred_loss: 0.5189 - val_resp_pred_loss: 0.6864 - val_card_pred_accuracy: 0.7545 - val_resp_pred_accuracy: 0.7452
# Epoch 11/50
# 136/136 [==============================] - 6s 47ms/step - loss: 0.9830 - card_pred_loss: 0.4517 - resp_pred_loss: 0.5313 - card_pred_accuracy: 0.8565 - resp_pred_accuracy: 0.8041 - val_loss: 1.1594 - val_card_pred_loss: 0.4894 - val_resp_pred_loss: 0.6700 - val_card_pred_accuracy: 0.7834 - val_resp_pred_accuracy: 0.7435
# Epoch 12/50
# 136/136 [==============================] - 6s 47ms/step - loss: 0.9748 - card_pred_loss: 0.4502 - resp_pred_loss: 0.5245 - card_pred_accuracy: 0.8602 - resp_pred_accuracy: 0.8041 - val_loss: 1.2056 - val_card_pred_loss: 0.5191 - val_resp_pred_loss: 0.6866 - val_card_pred_accuracy: 0.7621 - val_resp_pred_accuracy: 0.7378
# Epoch 13/50
# 136/136 [==============================] - 6s 47ms/step - loss: 0.9532 - card_pred_loss: 0.4323 - resp_pred_loss: 0.5209 - card_pred_accuracy: 0.8565 - resp_pred_accuracy: 0.8066 - val_loss: 1.1562 - val_card_pred_loss: 0.4817 - val_resp_pred_loss: 0.6745 - val_card_pred_accuracy: 0.7778 - val_resp_pred_accuracy: 0.7450
# Epoch 14/50
# 136/136 [==============================] - 7s 48ms/step - loss: 0.9528 - card_pred_loss: 0.4349 - resp_pred_loss: 0.5178 - card_pred_accuracy: 0.8607 - resp_pred_accuracy: 0.8064 - val_loss: 1.1770 - val_card_pred_loss: 0.4784 - val_resp_pred_loss: 0.6986 - val_card_pred_accuracy: 0.7825 - val_resp_pred_accuracy: 0.7442
# Epoch 15/50
# 136/136 [==============================] - 7s 48ms/step - loss: 0.9433 - card_pred_loss: 0.4306 - resp_pred_loss: 0.5127 - card_pred_accuracy: 0.8621 - resp_pred_accuracy: 0.8069 - val_loss: 1.1930 - val_card_pred_loss: 0.4777 - val_resp_pred_loss: 0.7153 - val_card_pred_accuracy: 0.7991 - val_resp_pred_accuracy: 0.7192
# Epoch 16/50
# 136/136 [==============================] - 7s 49ms/step - loss: 0.9399 - card_pred_loss: 0.4275 - resp_pred_loss: 0.5123 - card_pred_accuracy: 0.8618 - resp_pred_accuracy: 0.8075 - val_loss: 1.2018 - val_card_pred_loss: 0.4819 - val_resp_pred_loss: 0.7200 - val_card_pred_accuracy: 0.7798 - val_resp_pred_accuracy: 0.7318
# Epoch 17/50
# 136/136 [==============================] - 7s 48ms/step - loss: 0.9278 - card_pred_loss: 0.4227 - resp_pred_loss: 0.5051 - card_pred_accuracy: 0.8597 - resp_pred_accuracy: 0.8080 - val_loss: 1.1866 - val_card_pred_loss: 0.5060 - val_resp_pred_loss: 0.6806 - val_card_pred_accuracy: 0.7715 - val_resp_pred_accuracy: 0.7450
# Epoch 18/50
# 136/136 [==============================] - 6s 47ms/step - loss: 0.9269 - card_pred_loss: 0.4228 - resp_pred_loss: 0.5040 - card_pred_accuracy: 0.8610 - resp_pred_accuracy: 0.8094 - val_loss: 1.2028 - val_card_pred_loss: 0.5201 - val_resp_pred_loss: 0.6827 - val_card_pred_accuracy: 0.7469 - val_resp_pred_accuracy: 0.7461
# Epoch 19/50
# 136/136 [==============================] - 7s 48ms/step - loss: 0.9063 - card_pred_loss: 0.4062 - resp_pred_loss: 0.5001 - card_pred_accuracy: 0.8679 - resp_pred_accuracy: 0.8096 - val_loss: 1.2088 - val_card_pred_loss: 0.5367 - val_resp_pred_loss: 0.6721 - val_card_pred_accuracy: 0.7224 - val_resp_pred_accuracy: 0.7448
# Epoch 20/50
# 136/136 [==============================] - 7s 48ms/step - loss: 0.8896 - card_pred_loss: 0.3990 - resp_pred_loss: 0.4906 - card_pred_accuracy: 0.8579 - resp_pred_accuracy: 0.8114 - val_loss: 1.1632 - val_card_pred_loss: 0.4791 - val_resp_pred_loss: 0.6841 - val_card_pred_accuracy: 0.7763 - val_resp_pred_accuracy: 0.7453
# Epoch 21/50
# 136/136 [==============================] - 6s 48ms/step - loss: 0.8786 - card_pred_loss: 0.3956 - resp_pred_loss: 0.4830 - card_pred_accuracy: 0.8631 - resp_pred_accuracy: 0.8153 - val_loss: 1.2145 - val_card_pred_loss: 0.5368 - val_resp_pred_loss: 0.6778 - val_card_pred_accuracy: 0.7439 - val_resp_pred_accuracy: 0.7438
# Epoch 22/50
# 136/136 [==============================] - 6s 46ms/step - loss: 0.8751 - card_pred_loss: 0.3902 - resp_pred_loss: 0.4850 - card_pred_accuracy: 0.8667 - resp_pred_accuracy: 0.8155 - val_loss: 1.1960 - val_card_pred_loss: 0.4868 - val_resp_pred_loss: 0.7092 - val_card_pred_accuracy: 0.7796 - val_resp_pred_accuracy: 0.7257
# Epoch 23/50
# 136/136 [==============================] - 6s 47ms/step - loss: 0.8609 - card_pred_loss: 0.3811 - resp_pred_loss: 0.4798 - card_pred_accuracy: 0.8670 - resp_pred_accuracy: 0.8152 - val_loss: 1.2311 - val_card_pred_loss: 0.5167 - val_resp_pred_loss: 0.7144 - val_card_pred_accuracy: 0.7516 - val_resp_pred_accuracy: 0.7318
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 8). These functions will not be directly callable after loading.
# dict_keys(['loss', 'card_pred_loss', 'resp_pred_loss', 'card_pred_accuracy', 'resp_pred_accuracy', 'val_loss', 'val_card_pred_loss', 'val_resp_pred_loss', 'val_card_pred_accuracy', 'val_resp_pred_accuracy'])
# 241/241 [==============================] - 1s 4ms/step
# Fold 1:
# Epoch 1/50
# 131/131 [==============================] - 12s 51ms/step - loss: 1.9943 - card_pred_loss: 0.7837 - resp_pred_loss: 1.2106 - card_pred_accuracy: 0.7387 - resp_pred_accuracy: 0.6950 - val_loss: 1.1588 - val_card_pred_loss: 0.4647 - val_resp_pred_loss: 0.6941 - val_card_pred_accuracy: 0.8706 - val_resp_pred_accuracy: 0.7386
# Epoch 2/50
# 131/131 [==============================] - 6s 49ms/step - loss: 1.2173 - card_pred_loss: 0.5374 - resp_pred_loss: 0.6799 - card_pred_accuracy: 0.7921 - resp_pred_accuracy: 0.7538 - val_loss: 1.1508 - val_card_pred_loss: 0.4927 - val_resp_pred_loss: 0.6581 - val_card_pred_accuracy: 0.7723 - val_resp_pred_accuracy: 0.7318
# Epoch 3/50
# 131/131 [==============================] - 6s 47ms/step - loss: 1.1293 - card_pred_loss: 0.5012 - resp_pred_loss: 0.6281 - card_pred_accuracy: 0.8172 - resp_pred_accuracy: 0.7745 - val_loss: 1.0397 - val_card_pred_loss: 0.4409 - val_resp_pred_loss: 0.5989 - val_card_pred_accuracy: 0.8574 - val_resp_pred_accuracy: 0.7703
# Epoch 4/50
# 131/131 [==============================] - 7s 50ms/step - loss: 1.0828 - card_pred_loss: 0.4775 - resp_pred_loss: 0.6054 - card_pred_accuracy: 0.8271 - resp_pred_accuracy: 0.7840 - val_loss: 1.0583 - val_card_pred_loss: 0.4746 - val_resp_pred_loss: 0.5837 - val_card_pred_accuracy: 0.8069 - val_resp_pred_accuracy: 0.7695
# Epoch 5/50
# 131/131 [==============================] - 6s 48ms/step - loss: 1.0571 - card_pred_loss: 0.4671 - resp_pred_loss: 0.5900 - card_pred_accuracy: 0.8272 - resp_pred_accuracy: 0.7879 - val_loss: 1.0403 - val_card_pred_loss: 0.4625 - val_resp_pred_loss: 0.5778 - val_card_pred_accuracy: 0.8165 - val_resp_pred_accuracy: 0.7716
# Epoch 6/50
# 131/131 [==============================] - 7s 50ms/step - loss: 1.0259 - card_pred_loss: 0.4497 - resp_pred_loss: 0.5762 - card_pred_accuracy: 0.8364 - resp_pred_accuracy: 0.7931 - val_loss: 1.0421 - val_card_pred_loss: 0.4807 - val_resp_pred_loss: 0.5614 - val_card_pred_accuracy: 0.7945 - val_resp_pred_accuracy: 0.7845
# Epoch 7/50
# 131/131 [==============================] - 6s 47ms/step - loss: 1.0234 - card_pred_loss: 0.4479 - resp_pred_loss: 0.5755 - card_pred_accuracy: 0.8343 - resp_pred_accuracy: 0.7902 - val_loss: 1.0358 - val_card_pred_loss: 0.4639 - val_resp_pred_loss: 0.5719 - val_card_pred_accuracy: 0.8189 - val_resp_pred_accuracy: 0.7782
# Epoch 8/50
# 131/131 [==============================] - 6s 49ms/step - loss: 1.0062 - card_pred_loss: 0.4392 - resp_pred_loss: 0.5670 - card_pred_accuracy: 0.8373 - resp_pred_accuracy: 0.7925 - val_loss: 1.0403 - val_card_pred_loss: 0.4722 - val_resp_pred_loss: 0.5681 - val_card_pred_accuracy: 0.8123 - val_resp_pred_accuracy: 0.7673
# Epoch 9/50
# 131/131 [==============================] - 6s 48ms/step - loss: 0.9888 - card_pred_loss: 0.4274 - resp_pred_loss: 0.5614 - card_pred_accuracy: 0.8427 - resp_pred_accuracy: 0.7922 - val_loss: 1.0490 - val_card_pred_loss: 0.4719 - val_resp_pred_loss: 0.5771 - val_card_pred_accuracy: 0.8262 - val_resp_pred_accuracy: 0.7698
# Epoch 10/50
# 131/131 [==============================] - 6s 49ms/step - loss: 0.9737 - card_pred_loss: 0.4204 - resp_pred_loss: 0.5533 - card_pred_accuracy: 0.8457 - resp_pred_accuracy: 0.7952 - val_loss: 1.0297 - val_card_pred_loss: 0.4469 - val_resp_pred_loss: 0.5828 - val_card_pred_accuracy: 0.8216 - val_resp_pred_accuracy: 0.7718
# Epoch 11/50
# 131/131 [==============================] - 6s 48ms/step - loss: 0.9673 - card_pred_loss: 0.4179 - resp_pred_loss: 0.5494 - card_pred_accuracy: 0.8486 - resp_pred_accuracy: 0.7967 - val_loss: 1.0092 - val_card_pred_loss: 0.4394 - val_resp_pred_loss: 0.5698 - val_card_pred_accuracy: 0.8436 - val_resp_pred_accuracy: 0.7737
# Epoch 12/50
# 131/131 [==============================] - 6s 47ms/step - loss: 0.9528 - card_pred_loss: 0.4082 - resp_pred_loss: 0.5446 - card_pred_accuracy: 0.8508 - resp_pred_accuracy: 0.7967 - val_loss: 1.0707 - val_card_pred_loss: 0.5131 - val_resp_pred_loss: 0.5576 - val_card_pred_accuracy: 0.7740 - val_resp_pred_accuracy: 0.7857
# Epoch 13/50
# 131/131 [==============================] - 6s 47ms/step - loss: 0.9460 - card_pred_loss: 0.4052 - resp_pred_loss: 0.5408 - card_pred_accuracy: 0.8476 - resp_pred_accuracy: 0.7974 - val_loss: 1.0943 - val_card_pred_loss: 0.5137 - val_resp_pred_loss: 0.5806 - val_card_pred_accuracy: 0.7881 - val_resp_pred_accuracy: 0.7739
# Epoch 14/50
# 131/131 [==============================] - 6s 49ms/step - loss: 0.9296 - card_pred_loss: 0.3970 - resp_pred_loss: 0.5325 - card_pred_accuracy: 0.8547 - resp_pred_accuracy: 0.8012 - val_loss: 1.0836 - val_card_pred_loss: 0.5003 - val_resp_pred_loss: 0.5833 - val_card_pred_accuracy: 0.7899 - val_resp_pred_accuracy: 0.7697
# Epoch 15/50
# 131/131 [==============================] - 6s 48ms/step - loss: 0.9129 - card_pred_loss: 0.3872 - resp_pred_loss: 0.5257 - card_pred_accuracy: 0.8564 - resp_pred_accuracy: 0.7999 - val_loss: 1.1034 - val_card_pred_loss: 0.5355 - val_resp_pred_loss: 0.5679 - val_card_pred_accuracy: 0.7714 - val_resp_pred_accuracy: 0.7801
# Epoch 16/50
# 131/131 [==============================] - 6s 49ms/step - loss: 0.9096 - card_pred_loss: 0.3884 - resp_pred_loss: 0.5212 - card_pred_accuracy: 0.8557 - resp_pred_accuracy: 0.8023 - val_loss: 1.0743 - val_card_pred_loss: 0.4952 - val_resp_pred_loss: 0.5791 - val_card_pred_accuracy: 0.7948 - val_resp_pred_accuracy: 0.7649
# Epoch 17/50
# 131/131 [==============================] - 6s 47ms/step - loss: 0.9005 - card_pred_loss: 0.3797 - resp_pred_loss: 0.5209 - card_pred_accuracy: 0.8585 - resp_pred_accuracy: 0.8015 - val_loss: 1.1066 - val_card_pred_loss: 0.5216 - val_resp_pred_loss: 0.5850 - val_card_pred_accuracy: 0.7793 - val_resp_pred_accuracy: 0.7633
# Epoch 18/50
# 131/131 [==============================] - 6s 49ms/step - loss: 0.8877 - card_pred_loss: 0.3758 - resp_pred_loss: 0.5120 - card_pred_accuracy: 0.8597 - resp_pred_accuracy: 0.8030 - val_loss: 1.0666 - val_card_pred_loss: 0.4953 - val_resp_pred_loss: 0.5713 - val_card_pred_accuracy: 0.7842 - val_resp_pred_accuracy: 0.7748
# Epoch 19/50
# 131/131 [==============================] - 6s 48ms/step - loss: 0.8799 - card_pred_loss: 0.3731 - resp_pred_loss: 0.5068 - card_pred_accuracy: 0.8628 - resp_pred_accuracy: 0.8050 - val_loss: 1.1224 - val_card_pred_loss: 0.5665 - val_resp_pred_loss: 0.5559 - val_card_pred_accuracy: 0.7770 - val_resp_pred_accuracy: 0.7850
# Epoch 20/50
# 131/131 [==============================] - 6s 47ms/step - loss: 0.8614 - card_pred_loss: 0.3652 - resp_pred_loss: 0.4962 - card_pred_accuracy: 0.8618 - resp_pred_accuracy: 0.8101 - val_loss: 1.1438 - val_card_pred_loss: 0.5661 - val_resp_pred_loss: 0.5777 - val_card_pred_accuracy: 0.7472 - val_resp_pred_accuracy: 0.7739
# Epoch 21/50
# 131/131 [==============================] - 7s 50ms/step - loss: 0.8674 - card_pred_loss: 0.3690 - resp_pred_loss: 0.4984 - card_pred_accuracy: 0.8617 - resp_pred_accuracy: 0.8088 - val_loss: 1.0797 - val_card_pred_loss: 0.5153 - val_resp_pred_loss: 0.5645 - val_card_pred_accuracy: 0.7959 - val_resp_pred_accuracy: 0.7820
# 278/278 [==============================] - 1s 4ms/step
# Fold 2:
# Epoch 1/50
# 134/134 [==============================] - 11s 51ms/step - loss: 3.0049 - card_pred_loss: 1.3102 - resp_pred_loss: 1.6947 - card_pred_accuracy: 0.7586 - resp_pred_accuracy: 0.6953 - val_loss: 1.1972 - val_card_pred_loss: 0.4567 - val_resp_pred_loss: 0.7405 - val_card_pred_accuracy: 0.9192 - val_resp_pred_accuracy: 0.7301
# Epoch 2/50
# 134/134 [==============================] - 6s 48ms/step - loss: 1.2688 - card_pred_loss: 0.5890 - resp_pred_loss: 0.6798 - card_pred_accuracy: 0.8127 - resp_pred_accuracy: 0.7584 - val_loss: 1.1562 - val_card_pred_loss: 0.4789 - val_resp_pred_loss: 0.6774 - val_card_pred_accuracy: 0.8947 - val_resp_pred_accuracy: 0.7570
# Epoch 3/50
# 134/134 [==============================] - 6s 47ms/step - loss: 1.2128 - card_pred_loss: 0.5748 - resp_pred_loss: 0.6381 - card_pred_accuracy: 0.8038 - resp_pred_accuracy: 0.7712 - val_loss: 1.2126 - val_card_pred_loss: 0.5431 - val_resp_pred_loss: 0.6695 - val_card_pred_accuracy: 0.7796 - val_resp_pred_accuracy: 0.7626
# Epoch 4/50
# 134/134 [==============================] - 6s 47ms/step - loss: 1.1654 - card_pred_loss: 0.5509 - resp_pred_loss: 0.6146 - card_pred_accuracy: 0.7927 - resp_pred_accuracy: 0.7807 - val_loss: 1.0828 - val_card_pred_loss: 0.4444 - val_resp_pred_loss: 0.6384 - val_card_pred_accuracy: 0.8655 - val_resp_pred_accuracy: 0.7724
# Epoch 5/50
# 134/134 [==============================] - 6s 47ms/step - loss: 1.1228 - card_pred_loss: 0.5253 - resp_pred_loss: 0.5975 - card_pred_accuracy: 0.7965 - resp_pred_accuracy: 0.7863 - val_loss: 1.1724 - val_card_pred_loss: 0.5451 - val_resp_pred_loss: 0.6273 - val_card_pred_accuracy: 0.7451 - val_resp_pred_accuracy: 0.7739
# Epoch 6/50
# 134/134 [==============================] - 6s 48ms/step - loss: 1.0979 - card_pred_loss: 0.5090 - resp_pred_loss: 0.5889 - card_pred_accuracy: 0.8033 - resp_pred_accuracy: 0.7860 - val_loss: 1.1107 - val_card_pred_loss: 0.4854 - val_resp_pred_loss: 0.6253 - val_card_pred_accuracy: 0.7974 - val_resp_pred_accuracy: 0.7756
# Epoch 7/50
# 134/134 [==============================] - 7s 49ms/step - loss: 1.0684 - card_pred_loss: 0.4908 - resp_pred_loss: 0.5776 - card_pred_accuracy: 0.8115 - resp_pred_accuracy: 0.7925 - val_loss: 1.0544 - val_card_pred_loss: 0.4332 - val_resp_pred_loss: 0.6212 - val_card_pred_accuracy: 0.8407 - val_resp_pred_accuracy: 0.7781
# Epoch 8/50
# 134/134 [==============================] - 6s 48ms/step - loss: 1.0502 - card_pred_loss: 0.4822 - resp_pred_loss: 0.5680 - card_pred_accuracy: 0.8227 - resp_pred_accuracy: 0.7953 - val_loss: 1.0759 - val_card_pred_loss: 0.4597 - val_resp_pred_loss: 0.6163 - val_card_pred_accuracy: 0.7996 - val_resp_pred_accuracy: 0.7734
# Epoch 9/50
# 134/134 [==============================] - 6s 47ms/step - loss: 1.0377 - card_pred_loss: 0.4751 - resp_pred_loss: 0.5626 - card_pred_accuracy: 0.8242 - resp_pred_accuracy: 0.7949 - val_loss: 1.0362 - val_card_pred_loss: 0.4284 - val_resp_pred_loss: 0.6079 - val_card_pred_accuracy: 0.8522 - val_resp_pred_accuracy: 0.7832
# Epoch 10/50
# 134/134 [==============================] - 6s 47ms/step - loss: 1.0293 - card_pred_loss: 0.4710 - resp_pred_loss: 0.5583 - card_pred_accuracy: 0.8299 - resp_pred_accuracy: 0.7964 - val_loss: 1.1138 - val_card_pred_loss: 0.4944 - val_resp_pred_loss: 0.6194 - val_card_pred_accuracy: 0.7722 - val_resp_pred_accuracy: 0.7736
# Epoch 11/50
# 134/134 [==============================] - 6s 47ms/step - loss: 1.0212 - card_pred_loss: 0.4648 - resp_pred_loss: 0.5564 - card_pred_accuracy: 0.8333 - resp_pred_accuracy: 0.7952 - val_loss: 1.0532 - val_card_pred_loss: 0.4297 - val_resp_pred_loss: 0.6235 - val_card_pred_accuracy: 0.8272 - val_resp_pred_accuracy: 0.7614
# Epoch 12/50
# 134/134 [==============================] - 6s 48ms/step - loss: 1.0018 - card_pred_loss: 0.4563 - resp_pred_loss: 0.5455 - card_pred_accuracy: 0.8366 - resp_pred_accuracy: 0.7994 - val_loss: 1.0751 - val_card_pred_loss: 0.4568 - val_resp_pred_loss: 0.6184 - val_card_pred_accuracy: 0.7990 - val_resp_pred_accuracy: 0.7706
# Epoch 13/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9942 - card_pred_loss: 0.4508 - resp_pred_loss: 0.5434 - card_pred_accuracy: 0.8390 - resp_pred_accuracy: 0.7984 - val_loss: 1.0176 - val_card_pred_loss: 0.4150 - val_resp_pred_loss: 0.6025 - val_card_pred_accuracy: 0.8530 - val_resp_pred_accuracy: 0.7751
# Epoch 14/50
# 134/134 [==============================] - 6s 48ms/step - loss: 0.9858 - card_pred_loss: 0.4475 - resp_pred_loss: 0.5383 - card_pred_accuracy: 0.8396 - resp_pred_accuracy: 0.7997 - val_loss: 1.0306 - val_card_pred_loss: 0.4385 - val_resp_pred_loss: 0.5921 - val_card_pred_accuracy: 0.8383 - val_resp_pred_accuracy: 0.7873
# Epoch 15/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9785 - card_pred_loss: 0.4422 - resp_pred_loss: 0.5363 - card_pred_accuracy: 0.8387 - resp_pred_accuracy: 0.8013 - val_loss: 1.0418 - val_card_pred_loss: 0.4321 - val_resp_pred_loss: 0.6098 - val_card_pred_accuracy: 0.8298 - val_resp_pred_accuracy: 0.7750
# Epoch 16/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9710 - card_pred_loss: 0.4387 - resp_pred_loss: 0.5323 - card_pred_accuracy: 0.8398 - resp_pred_accuracy: 0.8016 - val_loss: 0.9903 - val_card_pred_loss: 0.3927 - val_resp_pred_loss: 0.5976 - val_card_pred_accuracy: 0.8408 - val_resp_pred_accuracy: 0.7741
# Epoch 17/50
# 134/134 [==============================] - 6s 48ms/step - loss: 0.9574 - card_pred_loss: 0.4338 - resp_pred_loss: 0.5235 - card_pred_accuracy: 0.8411 - resp_pred_accuracy: 0.8044 - val_loss: 1.0089 - val_card_pred_loss: 0.3987 - val_resp_pred_loss: 0.6101 - val_card_pred_accuracy: 0.8428 - val_resp_pred_accuracy: 0.7651
# Epoch 18/50
# 134/134 [==============================] - 7s 49ms/step - loss: 0.9496 - card_pred_loss: 0.4282 - resp_pred_loss: 0.5214 - card_pred_accuracy: 0.8441 - resp_pred_accuracy: 0.8034 - val_loss: 1.0048 - val_card_pred_loss: 0.3977 - val_resp_pred_loss: 0.6071 - val_card_pred_accuracy: 0.8553 - val_resp_pred_accuracy: 0.7821
# Epoch 19/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9468 - card_pred_loss: 0.4264 - resp_pred_loss: 0.5204 - card_pred_accuracy: 0.8468 - resp_pred_accuracy: 0.8051 - val_loss: 0.9809 - val_card_pred_loss: 0.3879 - val_resp_pred_loss: 0.5930 - val_card_pred_accuracy: 0.8576 - val_resp_pred_accuracy: 0.7818
# Epoch 20/50
# 134/134 [==============================] - 7s 49ms/step - loss: 0.9368 - card_pred_loss: 0.4213 - resp_pred_loss: 0.5154 - card_pred_accuracy: 0.8459 - resp_pred_accuracy: 0.8079 - val_loss: 0.9898 - val_card_pred_loss: 0.3928 - val_resp_pred_loss: 0.5970 - val_card_pred_accuracy: 0.8507 - val_resp_pred_accuracy: 0.7780
# Epoch 21/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9256 - card_pred_loss: 0.4164 - resp_pred_loss: 0.5092 - card_pred_accuracy: 0.8484 - resp_pred_accuracy: 0.8092 - val_loss: 1.0557 - val_card_pred_loss: 0.4517 - val_resp_pred_loss: 0.6040 - val_card_pred_accuracy: 0.8162 - val_resp_pred_accuracy: 0.7798
# Epoch 22/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9201 - card_pred_loss: 0.4129 - resp_pred_loss: 0.5072 - card_pred_accuracy: 0.8480 - resp_pred_accuracy: 0.8074 - val_loss: 1.0726 - val_card_pred_loss: 0.4621 - val_resp_pred_loss: 0.6105 - val_card_pred_accuracy: 0.8086 - val_resp_pred_accuracy: 0.7627
# Epoch 23/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9220 - card_pred_loss: 0.4156 - resp_pred_loss: 0.5064 - card_pred_accuracy: 0.8435 - resp_pred_accuracy: 0.8090 - val_loss: 0.9821 - val_card_pred_loss: 0.3803 - val_resp_pred_loss: 0.6019 - val_card_pred_accuracy: 0.8644 - val_resp_pred_accuracy: 0.7739
# Epoch 24/50
# 134/134 [==============================] - 7s 49ms/step - loss: 0.9056 - card_pred_loss: 0.4037 - resp_pred_loss: 0.5019 - card_pred_accuracy: 0.8484 - resp_pred_accuracy: 0.8097 - val_loss: 1.0254 - val_card_pred_loss: 0.4299 - val_resp_pred_loss: 0.5955 - val_card_pred_accuracy: 0.8283 - val_resp_pred_accuracy: 0.7706
# Epoch 25/50
# 134/134 [==============================] - 6s 47ms/step - loss: 0.9072 - card_pred_loss: 0.4073 - resp_pred_loss: 0.4999 - card_pred_accuracy: 0.8512 - resp_pred_accuracy: 0.8090 - val_loss: 1.0387 - val_card_pred_loss: 0.4350 - val_resp_pred_loss: 0.6037 - val_card_pred_accuracy: 0.8275 - val_resp_pred_accuracy: 0.7710
# Epoch 26/50
# 134/134 [==============================] - 7s 49ms/step - loss: 0.8937 - card_pred_loss: 0.4004 - resp_pred_loss: 0.4934 - card_pred_accuracy: 0.8521 - resp_pred_accuracy: 0.8103 - val_loss: 1.0134 - val_card_pred_loss: 0.4134 - val_resp_pred_loss: 0.6000 - val_card_pred_accuracy: 0.8374 - val_resp_pred_accuracy: 0.7793
# Epoch 27/50
# 134/134 [==============================] - 7s 49ms/step - loss: 0.8878 - card_pred_loss: 0.3958 - resp_pred_loss: 0.4920 - card_pred_accuracy: 0.8506 - resp_pred_accuracy: 0.8127 - val_loss: 1.0456 - val_card_pred_loss: 0.4295 - val_resp_pred_loss: 0.6160 - val_card_pred_accuracy: 0.8264 - val_resp_pred_accuracy: 0.7666
# Epoch 28/50
# 134/134 [==============================] - 6s 48ms/step - loss: 0.8769 - card_pred_loss: 0.3915 - resp_pred_loss: 0.4853 - card_pred_accuracy: 0.8521 - resp_pred_accuracy: 0.8122 - val_loss: 1.0853 - val_card_pred_loss: 0.4631 - val_resp_pred_loss: 0.6222 - val_card_pred_accuracy: 0.7762 - val_resp_pred_accuracy: 0.7656
# Epoch 29/50
# 134/134 [==============================] - 7s 49ms/step - loss: 0.8695 - card_pred_loss: 0.3869 - resp_pred_loss: 0.4826 - card_pred_accuracy: 0.8518 - resp_pred_accuracy: 0.8157 - val_loss: 1.1615 - val_card_pred_loss: 0.5205 - val_resp_pred_loss: 0.6410 - val_card_pred_accuracy: 0.7684 - val_resp_pred_accuracy: 0.7585
# 258/258 [==============================] - 1s 4ms/step
# Fold 3:
# Epoch 1/50
# 135/135 [==============================] - 11s 55ms/step - loss: 2.2029 - card_pred_loss: 0.8797 - resp_pred_loss: 1.3232 - card_pred_accuracy: 0.7680 - resp_pred_accuracy: 0.6748 - val_loss: 1.1823 - val_card_pred_loss: 0.5682 - val_resp_pred_loss: 0.6141 - val_card_pred_accuracy: 0.7609 - val_resp_pred_accuracy: 0.7868
# Epoch 2/50
# 135/135 [==============================] - 7s 48ms/step - loss: 1.2503 - card_pred_loss: 0.5720 - resp_pred_loss: 0.6782 - card_pred_accuracy: 0.8384 - resp_pred_accuracy: 0.7526 - val_loss: 1.0646 - val_card_pred_loss: 0.5093 - val_resp_pred_loss: 0.5554 - val_card_pred_accuracy: 0.7999 - val_resp_pred_accuracy: 0.8100
# Epoch 3/50
# 135/135 [==============================] - 7s 50ms/step - loss: 1.1976 - card_pred_loss: 0.5584 - resp_pred_loss: 0.6392 - card_pred_accuracy: 0.8515 - resp_pred_accuracy: 0.7702 - val_loss: 1.0602 - val_card_pred_loss: 0.5253 - val_resp_pred_loss: 0.5349 - val_card_pred_accuracy: 0.7857 - val_resp_pred_accuracy: 0.8149
# Epoch 4/50
# 135/135 [==============================] - 7s 49ms/step - loss: 1.1708 - card_pred_loss: 0.5564 - resp_pred_loss: 0.6144 - card_pred_accuracy: 0.8524 - resp_pred_accuracy: 0.7814 - val_loss: 1.0133 - val_card_pred_loss: 0.4893 - val_resp_pred_loss: 0.5241 - val_card_pred_accuracy: 0.7895 - val_resp_pred_accuracy: 0.8216
# Epoch 5/50
# 135/135 [==============================] - 6s 48ms/step - loss: 1.1445 - card_pred_loss: 0.5443 - resp_pred_loss: 0.6002 - card_pred_accuracy: 0.8459 - resp_pred_accuracy: 0.7865 - val_loss: 1.0435 - val_card_pred_loss: 0.5192 - val_resp_pred_loss: 0.5244 - val_card_pred_accuracy: 0.7725 - val_resp_pred_accuracy: 0.8181
# Epoch 6/50
# 135/135 [==============================] - 7s 49ms/step - loss: 1.1197 - card_pred_loss: 0.5288 - resp_pred_loss: 0.5909 - card_pred_accuracy: 0.8373 - resp_pred_accuracy: 0.7870 - val_loss: 0.9984 - val_card_pred_loss: 0.4965 - val_resp_pred_loss: 0.5019 - val_card_pred_accuracy: 0.7609 - val_resp_pred_accuracy: 0.8132
# Epoch 7/50
# 135/135 [==============================] - 7s 49ms/step - loss: 1.1029 - card_pred_loss: 0.5216 - resp_pred_loss: 0.5812 - card_pred_accuracy: 0.8266 - resp_pred_accuracy: 0.7927 - val_loss: 0.9475 - val_card_pred_loss: 0.4396 - val_resp_pred_loss: 0.5079 - val_card_pred_accuracy: 0.7686 - val_resp_pred_accuracy: 0.8246
# Epoch 8/50
# 135/135 [==============================] - 7s 54ms/step - loss: 1.0905 - card_pred_loss: 0.5135 - resp_pred_loss: 0.5771 - card_pred_accuracy: 0.8231 - resp_pred_accuracy: 0.7936 - val_loss: 0.9801 - val_card_pred_loss: 0.4721 - val_resp_pred_loss: 0.5079 - val_card_pred_accuracy: 0.7446 - val_resp_pred_accuracy: 0.8224
# Epoch 9/50
# 135/135 [==============================] - 6s 47ms/step - loss: 1.0848 - card_pred_loss: 0.5104 - resp_pred_loss: 0.5744 - card_pred_accuracy: 0.8194 - resp_pred_accuracy: 0.7931 - val_loss: 0.9270 - val_card_pred_loss: 0.4326 - val_resp_pred_loss: 0.4944 - val_card_pred_accuracy: 0.7931 - val_resp_pred_accuracy: 0.8278
# Epoch 10/50
# 135/135 [==============================] - 7s 50ms/step - loss: 1.0746 - card_pred_loss: 0.5077 - resp_pred_loss: 0.5670 - card_pred_accuracy: 0.8190 - resp_pred_accuracy: 0.7956 - val_loss: 0.9190 - val_card_pred_loss: 0.4332 - val_resp_pred_loss: 0.4858 - val_card_pred_accuracy: 0.7669 - val_resp_pred_accuracy: 0.8222
# Epoch 11/50
# 135/135 [==============================] - 6s 46ms/step - loss: 1.0652 - card_pred_loss: 0.4993 - resp_pred_loss: 0.5659 - card_pred_accuracy: 0.8235 - resp_pred_accuracy: 0.7981 - val_loss: 0.9696 - val_card_pred_loss: 0.4477 - val_resp_pred_loss: 0.5218 - val_card_pred_accuracy: 0.7624 - val_resp_pred_accuracy: 0.8192
# Epoch 12/50
# 135/135 [==============================] - 7s 49ms/step - loss: 1.0443 - card_pred_loss: 0.4894 - resp_pred_loss: 0.5550 - card_pred_accuracy: 0.8198 - resp_pred_accuracy: 0.7987 - val_loss: 0.9257 - val_card_pred_loss: 0.4315 - val_resp_pred_loss: 0.4942 - val_card_pred_accuracy: 0.7659 - val_resp_pred_accuracy: 0.8221
# Epoch 13/50
# 135/135 [==============================] - 6s 47ms/step - loss: 1.0368 - card_pred_loss: 0.4855 - resp_pred_loss: 0.5513 - card_pred_accuracy: 0.8218 - resp_pred_accuracy: 0.7992 - val_loss: 0.9825 - val_card_pred_loss: 0.4618 - val_resp_pred_loss: 0.5206 - val_card_pred_accuracy: 0.7252 - val_resp_pred_accuracy: 0.8179
# Epoch 14/50
# 135/135 [==============================] - 7s 50ms/step - loss: 1.0282 - card_pred_loss: 0.4792 - resp_pred_loss: 0.5490 - card_pred_accuracy: 0.8105 - resp_pred_accuracy: 0.7983 - val_loss: 0.9237 - val_card_pred_loss: 0.4327 - val_resp_pred_loss: 0.4910 - val_card_pred_accuracy: 0.7803 - val_resp_pred_accuracy: 0.8221
# Epoch 15/50
# 135/135 [==============================] - 7s 49ms/step - loss: 1.0208 - card_pred_loss: 0.4766 - resp_pred_loss: 0.5441 - card_pred_accuracy: 0.8164 - resp_pred_accuracy: 0.7966 - val_loss: 0.9497 - val_card_pred_loss: 0.4575 - val_resp_pred_loss: 0.4922 - val_card_pred_accuracy: 0.7393 - val_resp_pred_accuracy: 0.8217
# Epoch 16/50
# 135/135 [==============================] - 7s 50ms/step - loss: 1.0116 - card_pred_loss: 0.4731 - resp_pred_loss: 0.5384 - card_pred_accuracy: 0.8163 - resp_pred_accuracy: 0.7993 - val_loss: 0.9790 - val_card_pred_loss: 0.4480 - val_resp_pred_loss: 0.5310 - val_card_pred_accuracy: 0.7604 - val_resp_pred_accuracy: 0.8043
# Epoch 17/50
# 135/135 [==============================] - 6s 47ms/step - loss: 1.0042 - card_pred_loss: 0.4694 - resp_pred_loss: 0.5349 - card_pred_accuracy: 0.8187 - resp_pred_accuracy: 0.8015 - val_loss: 0.9221 - val_card_pred_loss: 0.4468 - val_resp_pred_loss: 0.4753 - val_card_pred_accuracy: 0.7397 - val_resp_pred_accuracy: 0.8224
# Epoch 18/50
# 135/135 [==============================] - 6s 48ms/step - loss: 1.0010 - card_pred_loss: 0.4674 - resp_pred_loss: 0.5336 - card_pred_accuracy: 0.8116 - resp_pred_accuracy: 0.8024 - val_loss: 0.9674 - val_card_pred_loss: 0.4720 - val_resp_pred_loss: 0.4954 - val_card_pred_accuracy: 0.7303 - val_resp_pred_accuracy: 0.8140
# Epoch 19/50
# 135/135 [==============================] - 7s 49ms/step - loss: 0.9880 - card_pred_loss: 0.4591 - resp_pred_loss: 0.5289 - card_pred_accuracy: 0.8192 - resp_pred_accuracy: 0.8029 - val_loss: 0.9597 - val_card_pred_loss: 0.4783 - val_resp_pred_loss: 0.4814 - val_card_pred_accuracy: 0.7290 - val_resp_pred_accuracy: 0.8210
# Epoch 20/50
# 135/135 [==============================] - 6s 48ms/step - loss: 0.9735 - card_pred_loss: 0.4492 - resp_pred_loss: 0.5243 - card_pred_accuracy: 0.8199 - resp_pred_accuracy: 0.8033 - val_loss: 0.9397 - val_card_pred_loss: 0.4618 - val_resp_pred_loss: 0.4778 - val_card_pred_accuracy: 0.7400 - val_resp_pred_accuracy: 0.8206
# 249/249 [==============================] - 1s 4ms/step
# Fold 4:
# Epoch 1/50
# 128/128 [==============================] - 11s 54ms/step - loss: 2.7071 - card_pred_loss: 1.2376 - resp_pred_loss: 1.4695 - card_pred_accuracy: 0.7423 - resp_pred_accuracy: 0.6630 - val_loss: 1.2385 - val_card_pred_loss: 0.5864 - val_resp_pred_loss: 0.6522 - val_card_pred_accuracy: 0.7313 - val_resp_pred_accuracy: 0.7894
# Epoch 2/50
# 128/128 [==============================] - 6s 48ms/step - loss: 1.2963 - card_pred_loss: 0.5862 - resp_pred_loss: 0.7101 - card_pred_accuracy: 0.8095 - resp_pred_accuracy: 0.7425 - val_loss: 1.1978 - val_card_pred_loss: 0.5059 - val_resp_pred_loss: 0.6919 - val_card_pred_accuracy: 0.8470 - val_resp_pred_accuracy: 0.7719
# Epoch 3/50
# 128/128 [==============================] - 6s 49ms/step - loss: 1.2444 - card_pred_loss: 0.5769 - resp_pred_loss: 0.6675 - card_pred_accuracy: 0.8093 - resp_pred_accuracy: 0.7621 - val_loss: 1.1028 - val_card_pred_loss: 0.4642 - val_resp_pred_loss: 0.6386 - val_card_pred_accuracy: 0.8576 - val_resp_pred_accuracy: 0.8025
# Epoch 4/50
# 128/128 [==============================] - 6s 50ms/step - loss: 1.1965 - card_pred_loss: 0.5579 - resp_pred_loss: 0.6386 - card_pred_accuracy: 0.7976 - resp_pred_accuracy: 0.7720 - val_loss: 1.1508 - val_card_pred_loss: 0.4884 - val_resp_pred_loss: 0.6624 - val_card_pred_accuracy: 0.7778 - val_resp_pred_accuracy: 0.8008
# Epoch 5/50
# 128/128 [==============================] - 6s 51ms/step - loss: 1.1704 - card_pred_loss: 0.5444 - resp_pred_loss: 0.6260 - card_pred_accuracy: 0.7860 - resp_pred_accuracy: 0.7765 - val_loss: 1.0256 - val_card_pred_loss: 0.4205 - val_resp_pred_loss: 0.6052 - val_card_pred_accuracy: 0.8692 - val_resp_pred_accuracy: 0.8064
# Epoch 6/50
# 128/128 [==============================] - 6s 49ms/step - loss: 1.1462 - card_pred_loss: 0.5335 - resp_pred_loss: 0.6127 - card_pred_accuracy: 0.7855 - resp_pred_accuracy: 0.7824 - val_loss: 1.0758 - val_card_pred_loss: 0.5048 - val_resp_pred_loss: 0.5710 - val_card_pred_accuracy: 0.7715 - val_resp_pred_accuracy: 0.8118
# Epoch 7/50
# 128/128 [==============================] - 6s 50ms/step - loss: 1.1297 - card_pred_loss: 0.5228 - resp_pred_loss: 0.6069 - card_pred_accuracy: 0.7842 - resp_pred_accuracy: 0.7815 - val_loss: 1.0553 - val_card_pred_loss: 0.4542 - val_resp_pred_loss: 0.6012 - val_card_pred_accuracy: 0.7874 - val_resp_pred_accuracy: 0.8061
# Epoch 8/50
# 128/128 [==============================] - 6s 48ms/step - loss: 1.1193 - card_pred_loss: 0.5212 - resp_pred_loss: 0.5981 - card_pred_accuracy: 0.7845 - resp_pred_accuracy: 0.7829 - val_loss: 1.0710 - val_card_pred_loss: 0.5114 - val_resp_pred_loss: 0.5596 - val_card_pred_accuracy: 0.7459 - val_resp_pred_accuracy: 0.8089
# Epoch 9/50
# 128/128 [==============================] - 6s 50ms/step - loss: 1.1138 - card_pred_loss: 0.5187 - resp_pred_loss: 0.5951 - card_pred_accuracy: 0.7857 - resp_pred_accuracy: 0.7857 - val_loss: 1.1387 - val_card_pred_loss: 0.5639 - val_resp_pred_loss: 0.5748 - val_card_pred_accuracy: 0.6958 - val_resp_pred_accuracy: 0.8156
# Epoch 10/50
# 128/128 [==============================] - 6s 49ms/step - loss: 1.1026 - card_pred_loss: 0.5051 - resp_pred_loss: 0.5975 - card_pred_accuracy: 0.7861 - resp_pred_accuracy: 0.7815 - val_loss: 1.1005 - val_card_pred_loss: 0.5117 - val_resp_pred_loss: 0.5888 - val_card_pred_accuracy: 0.7600 - val_resp_pred_accuracy: 0.7983
# Epoch 11/50
# 128/128 [==============================] - 6s 49ms/step - loss: 1.0849 - card_pred_loss: 0.4917 - resp_pred_loss: 0.5932 - card_pred_accuracy: 0.7971 - resp_pred_accuracy: 0.7808 - val_loss: 1.1340 - val_card_pred_loss: 0.5054 - val_resp_pred_loss: 0.6286 - val_card_pred_accuracy: 0.7638 - val_resp_pred_accuracy: 0.7866
# Epoch 12/50
# 128/128 [==============================] - 6s 49ms/step - loss: 1.0572 - card_pred_loss: 0.4708 - resp_pred_loss: 0.5864 - card_pred_accuracy: 0.8162 - resp_pred_accuracy: 0.7809 - val_loss: 0.9975 - val_card_pred_loss: 0.4589 - val_resp_pred_loss: 0.5387 - val_card_pred_accuracy: 0.8238 - val_resp_pred_accuracy: 0.8191
# Epoch 13/50
# 128/128 [==============================] - 6s 50ms/step - loss: 1.0408 - card_pred_loss: 0.4583 - resp_pred_loss: 0.5825 - card_pred_accuracy: 0.8245 - resp_pred_accuracy: 0.7799 - val_loss: 1.1301 - val_card_pred_loss: 0.5362 - val_resp_pred_loss: 0.5939 - val_card_pred_accuracy: 0.7556 - val_resp_pred_accuracy: 0.8015
# Epoch 14/50
# 128/128 [==============================] - 6s 50ms/step - loss: 1.0277 - card_pred_loss: 0.4507 - resp_pred_loss: 0.5770 - card_pred_accuracy: 0.8289 - resp_pred_accuracy: 0.7836 - val_loss: 1.0351 - val_card_pred_loss: 0.4385 - val_resp_pred_loss: 0.5966 - val_card_pred_accuracy: 0.8114 - val_resp_pred_accuracy: 0.7908
# Epoch 15/50
# 128/128 [==============================] - 6s 50ms/step - loss: 1.0076 - card_pred_loss: 0.4363 - resp_pred_loss: 0.5713 - card_pred_accuracy: 0.8352 - resp_pred_accuracy: 0.7877 - val_loss: 1.0844 - val_card_pred_loss: 0.4408 - val_resp_pred_loss: 0.6435 - val_card_pred_accuracy: 0.8212 - val_resp_pred_accuracy: 0.7779
# Epoch 16/50
# 128/128 [==============================] - 6s 50ms/step - loss: 0.9925 - card_pred_loss: 0.4297 - resp_pred_loss: 0.5627 - card_pred_accuracy: 0.8422 - resp_pred_accuracy: 0.7870 - val_loss: 1.1494 - val_card_pred_loss: 0.5067 - val_resp_pred_loss: 0.6427 - val_card_pred_accuracy: 0.7818 - val_resp_pred_accuracy: 0.8017
# Epoch 17/50
# 128/128 [==============================] - 6s 50ms/step - loss: 0.9770 - card_pred_loss: 0.4197 - resp_pred_loss: 0.5574 - card_pred_accuracy: 0.8426 - resp_pred_accuracy: 0.7883 - val_loss: 1.0901 - val_card_pred_loss: 0.4638 - val_resp_pred_loss: 0.6263 - val_card_pred_accuracy: 0.8023 - val_resp_pred_accuracy: 0.8034
# Epoch 18/50
# 128/128 [==============================] - 6s 50ms/step - loss: 0.9876 - card_pred_loss: 0.4318 - resp_pred_loss: 0.5558 - card_pred_accuracy: 0.8426 - resp_pred_accuracy: 0.7918 - val_loss: 1.0993 - val_card_pred_loss: 0.4564 - val_resp_pred_loss: 0.6429 - val_card_pred_accuracy: 0.7924 - val_resp_pred_accuracy: 0.8081
# Epoch 19/50
# 128/128 [==============================] - 6s 50ms/step - loss: 0.9911 - card_pred_loss: 0.4371 - resp_pred_loss: 0.5540 - card_pred_accuracy: 0.8413 - resp_pred_accuracy: 0.7926 - val_loss: 1.0869 - val_card_pred_loss: 0.4450 - val_resp_pred_loss: 0.6420 - val_card_pred_accuracy: 0.8310 - val_resp_pred_accuracy: 0.8126
# Epoch 20/50
# 128/128 [==============================] - 6s 49ms/step - loss: 0.9756 - card_pred_loss: 0.4266 - resp_pred_loss: 0.5490 - card_pred_accuracy: 0.8457 - resp_pred_accuracy: 0.7898 - val_loss: 1.1557 - val_card_pred_loss: 0.5093 - val_resp_pred_loss: 0.6464 - val_card_pred_accuracy: 0.7592 - val_resp_pred_accuracy: 0.7992
# Epoch 21/50
# 128/128 [==============================] - 6s 48ms/step - loss: 0.9721 - card_pred_loss: 0.4242 - resp_pred_loss: 0.5479 - card_pred_accuracy: 0.8451 - resp_pred_accuracy: 0.7912 - val_loss: 1.1586 - val_card_pred_loss: 0.5035 - val_resp_pred_loss: 0.6551 - val_card_pred_accuracy: 0.7807 - val_resp_pred_accuracy: 0.7921
# Epoch 22/50
# 128/128 [==============================] - 6s 51ms/step - loss: 0.9554 - card_pred_loss: 0.4129 - resp_pred_loss: 0.5425 - card_pred_accuracy: 0.8504 - resp_pred_accuracy: 0.7900 - val_loss: 1.3066 - val_card_pred_loss: 0.5106 - val_resp_pred_loss: 0.7960 - val_card_pred_accuracy: 0.7996 - val_resp_pred_accuracy: 0.8080
# 300/300 [==============================] - 1s 4ms/step
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Card > Loss: 0.52 - Accuracy: 75.16%
# > Fold 1 - Resp > Loss: 0.71 - Accuracy: 73.18%
# > Fold 2 - Card > Loss: 0.52 - Accuracy: 79.59%
# > Fold 2 - Resp > Loss: 0.56 - Accuracy: 78.20%
# > Fold 3 - Card > Loss: 0.52 - Accuracy: 76.84%
# > Fold 3 - Resp > Loss: 0.64 - Accuracy: 75.85%
# > Fold 4 - Card > Loss: 0.46 - Accuracy: 74.00%
# > Fold 4 - Resp > Loss: 0.48 - Accuracy: 82.06%
# > Fold 5 - Card > Loss: 0.51 - Accuracy: 79.96%
# > Fold 5 - Resp > Loss:  0.8 - Accuracy: 80.80%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Card Accuracy: 77.11 (+- 2.362)
# > Reso Accuracy: 78.02 (+- 3.232)
# ------------------------------------------------------------------------
# Total Training time = 0:13:25 HH:MM:SS

# %%
# For debugging
# my_model = keras.models.load_model('my_model')
# X_valid_dict = np.load('X_valid_dict.npy',allow_pickle='TRUE').item()
# y_pred = my_model.predict(X_valid_dict)
# print(y_pred[0])

# %% [markdown]
# # Save each confusion matrix separately, then plot/save side-by-side

# %%
# much of this leveraged from tsmodel_throwdown in load_data_time_series
label_names = ['Cardiac','Respiratory']

#acknowledgement to @MikeHordecki https://stackoverflow.com/questions/522563/accessing-the-index-in-for-loops
for idx, curr_lname in enumerate(label_names):   
    if (idx == 0):
        y_valid = card_y_valid
        y_pred =  card_y_pred
        class_names = ['Normal','Abnormal'] # cardiac events
    elif (idx == 1):
        y_valid = resp_y_valid
        y_pred =  resp_y_pred
        class_names = ['Normal','Apnea','Hypopnea'] # Rep events
    else:
        print ("Something went wrong!")
        model = None # just to keep from running erroneous pass

    class_rpt = 'Classification Report for PSG-Audio ' + curr_lname + ' events\n'
    class_rpt += (classification_report(y_valid, y_pred, target_names = class_names))
    #y_test_act = np.argmax(y_test, axis=-1) # undo one-hot encoding

    cm = confusion_matrix(y_valid, y_pred)
    cm_df = pd.DataFrame(cm,
                        index = class_names, 
                        columns = class_names)
    cm_height = 6 # was 1.2*len(t_names)/2
    cm_width = 6 # was len(t_names)/2)
    fig = plt.figure(figsize=(cm_width,cm_height)) # num classes => size
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
    #plt.title(curr_mname +' using '+dataset+'\nAccuracy:{0:.3f}'.format(accuracy_score(y_test_act, y_pred)))
    #plt.title('PSG-Audio:' + curr_lname)
    font_title = {'family':'monospace','color':'black','size':12}
    plt.title(class_rpt, fontdict = font_title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout() # keeps labels from being cutoff when saving as pdf
    cmplot_name = 'psg-audio_'+ curr_lname + '_cm.png'
    plt.savefig(cmplot_name, dpi = 300) 
    plt.close() # otherwise plots still get displayed even w/o plt.show()
    #plt.show()

# read in plots and show side-by-side
fig, axs = plt.subplots(nrows=1, ncols=2)#, figsize = (40,10))
fig.set_size_inches(12,24)
axs[0].set_axis_off() # so outer boarder and numbers do not appear
axs[1].set_axis_off()
axs[0].imshow(plt.imread('psg-audio_Cardiac_cm.png'))
axs[1].imshow(plt.imread('psg-audio_Respiratory_cm.png'))
plt.tight_layout()
plt.savefig('psg-audio_Card_Resp_cm.png', dpi = 300) # don't forget to download!
plt.show()

# %% [markdown]
# # STOP - the following code is to load the data from and save figures to google drive.
# You are welcome to use it, but it is untested outside of my environment.

# %%
def get_load_data_utils():
    """checks for local file, if none downloads from IMICS repository.
    Assumes a global my_dir has been defined (default is my_dir = ".")
    :return: nothing"""
    fname = 'load_data_utils.py'
    ffname = os.path.join(my_dir,fname)
    if (os.path.exists(ffname)):
        print ("Local load_data_utils.py found, skipping download")
    else:
        print("Downloading",fname, "from IMICS git repo")
        urllib.request.urlretrieve("https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/load_data_utils.py", filename=fname)
if interactive:
    get_load_data_utils()
# Out:
# Downloading load_data_utils.py from IMICS git repo

# %%
from load_data_utils import get_env_info
from load_data_utils import get_log_ffname
from load_data_utils import tabulate_numpy_arrays
from load_data_utils import channel_powerset
if interactive:
    print('My env_info: \n' + get_env_info())
# Out:
# My env_info:
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# GPU: name, driver_version, memory.total [MiB]
# Tesla T4, 510.47.03, 15360 MiB

# %%
save_log = False # set to False to avoid a problem if accidentally run...
# alternate confusion matrix with fig object to save
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm,
                    index = class_names, 
                    columns = class_names)
fig = plt.figure(figsize=(6.5,5))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
#plt.title('Insert title here\n
#plt.title('Accuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.title('Accuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout() # keeps labels from being cutoff when saving as pdf
plt.show()
if save_log:
    log_ffname = get_log_ffname(
    log_file_dir = '/content/drive/My Drive/Colab_Run_Results',
    base_fname = "PSG_Multi_Output_Work")
    print("Saving results to", log_ffname)
    with open(log_ffname, "a") as file_object:
        file_object.write("Generated by Evaluate_Model_PSG-Audio.ipynb\n")
        file_object.write("Processed PSG with 5 fold via sklearn GroupKFold\n")
        file_object.write("Final Accuracy: %0.3f\n" %accuracy_score(y_test, y_pred))
        file_object.write("Classification Report\n")
        file_object.write(classification_report(y_test, y_pred, target_names=class_names))
        file_object.write("Confusion Matrix\n")
        file_object.write(str(cm))
    cm_ffname = log_ffname.split('.')[0] + '_cm.pdf'
    print("saving cm plot as",cm_ffname)
    fig.savefig(cm_ffname,format='pdf', dpi=1200)
    full_model_fname = log_ffname.split('.')[0] + '_model.txt'
    with open(full_model_fname, "a") as file_object:
        model.summary(print_fn=lambda x: file_object.write(x + '\n'))
        #acknowledgement https://stackoverflow.com/users/14951382/sparklingdew
    #plot using keras function
    #ref https://keras.io/api/utils/model_plotting_utils/
    full_mplot_fname = log_ffname.split('.')[0] + '_model.png'
    keras.utils.plot_model(model, to_file=full_mplot_fname, show_shapes=True)

# %% [markdown]
# #Resp Evaluate Model PSG-Audio
#
# This version modified for respiratory classification.
#
# Author:  [Lee B. Hinkle](https://userweb.cs.txstate.edu/~lbh31/), [IMICS Lab](https://imics.wp.txstate.edu/), Texas State University, 2023
#
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Attribution-ShareAlike 4.0 International License</a>.
#
# TODO:
#
# *

# %% [markdown]
# # Imports

# %%
import os
import shutil
import time
from datetime import datetime
from datetime import date
from datetime import timedelta # for calculating training time
from random import randrange # for plotting samples
import numpy as np
import matplotlib.pyplot as plt # for plotting training curves
from tabulate import tabulate # for verbose tables, showing data
import tensorflow as tf
from tensorflow import keras #added to save model
from tensorflow.keras import layers #format matches MNIST example
from tensorflow.keras.callbacks import EarlyStopping
#imports for computing and displaying output metrics
import seaborn as sns
import pandas as pd
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import compute_sample_weight
import sys
import urllib.request # to get files from web w/o !wget
from shutil import unpack_archive # to unzip

# %%
my_dir = '.' # replace with absolute path if desired
interactive = True # runs simple calls for most cells
# verbose = True

working_dir = os.path.join(my_dir,'psg_dataset') # create local directory
if not os.path.exists(working_dir):
    os.mkdir(working_dir)

# %% [markdown]
# # Get small or full processed PSG-Audio numpy arrays
# See PSG-Audio_load_dataset_for_multi-output.ipynb for info, this is source of the arrays.

# %%
use_small = True # arrays are 1/10th the size for shorter download/train time
if use_small:
    version = "small"
    flist = ["small_x_train.npy", "small_y_train.npy", "small_sub_train.npy"]
else:
    version = "full"
    flist = ["x_train.npy", "y_train.npy", "sub_train.npy"]

# %%
# this needs to be per file apparently.
# !gdown.download_folder('https://drive.google.com/drive/folders/10G5SbdPKZWpZSBkO_II8dR4SoOfEJJwz?usp=sharing')

# !gdown "1zo_Amyb_vbAL1VKpa1IKtuHpL5Gw9IaG&confirm=t" # small_x_train
# !gdown "1_ZFknIBTNaCS7lCILDM0loUOFUUzz8EZ&confirm=t" # small_y_train
# !gdown "1KbOqMdPlOUaT1TQMY_NTp-oKqnRzelfb&confirm=t" # small_sub_train
working_dir = "." # just to stay compatible, gdown uses current dir.
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zo_Amyb_vbAL1VKpa1IKtuHpL5Gw9IaG&confirm=t
# To: /content/small_x_train.npy
# 100% 610M/610M [00:18<00:00, 33.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_ZFknIBTNaCS7lCILDM0loUOFUUzz8EZ&confirm=t
# To: /content/small_y_train.npy
# 100% 84.8k/84.8k [00:00<00:00, 83.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KbOqMdPlOUaT1TQMY_NTp-oKqnRzelfb&confirm=t
# To: /content/small_sub_train.npy
# 100% 84.8k/84.8k [00:00<00:00, 59.0MB/s]

# %%
def read_arrays():
    """read in the arrays - leaving test arrays out of this for now (just tuning model)"""
    if use_small:
        print("Reading in small arrays")
        X = np.load(os.path.join(working_dir, 'small_x_train.npy'))
        y = np.load(os.path.join(working_dir, 'small_y_train.npy'))
        sub = np.load(os.path.join(working_dir, 'small_sub_train.npy'))
    else:
        print("Reading in full arrays")
        X = np.load(os.path.join(working_dir, 'x_train.npy'))
        y = np.load(os.path.join(working_dir, 'y_train.npy'))
        sub = np.load(os.path.join(working_dir, 'sub_train.npy'))
    print("Reading arrays from npy files")
    headers = ("Array","shape", "data type")
    mydata = [("X:", X.shape, X.dtype),
            ("y:", y.shape, y.dtype),
            ("sub:", sub.shape, sub.dtype)]
    print("\n",tabulate(mydata, headers=headers))
    return X, y, sub
if interactive:
    X, y, sub = read_arrays()
# Out:
# Reading in small arrays
# Reading arrays from npy files
#
#  Array    shape             data type
# -------  ----------------  -----------
# X:       (42333, 300, 12)  float32
# y:       (42333, 2)        int8
# sub:     (42333, 1)        uint16

# %% [markdown]
# # Split X by Signal Modality and y by Event Type

# %%
# Seems like it would be better to pass X directly and handle in the model
# but I don't see such a preprocessing method.   Maybe it is more obvious?
# https://keras.io/guides/preprocessing_layers/

X_eeg = X[:,:,0:3] # first 3 channels (0,1,2)
X_eog = X[:,:,3:5] # channels 3 and 4
X_emg = X[:,:,5:6] # just channel 5
X_ecg = X[:,:,8:9] # ECG - this is a goofy way to keep shape w/ one channel...
X_flow = X[:,:,9:10] # ECG - this is a goofy way to keep shape w/ one channel...
X_reff = X[:,:,10:12] # abd, thor respiratory effort

y_card = y[:,0:1]
y_resp = y[:,1:2]

X_all = [X_eeg, X_eog, X_emg, X_ecg, X_flow, X_reff]
X_all_dict = {'eeg': X_eeg, 'eog':X_eog, 'emg':X_emg, 'ecg':X_ecg, 'flow':X_flow, 'reff':X_reff}
y_all = [y_card, y_resp]
y_all_dict = {'card':y_card,'resp':y_resp}
for key,item in X_all_dict.items():
    print(key,item.shape)
for key, item in y_all_dict.items():
    print(key,item.shape)
# Out:
# eeg (42333, 300, 3)
# eog (42333, 300, 2)
# emg (42333, 300, 1)
# ecg (42333, 300, 1)
# flow (42333, 300, 1)
# reff (42333, 300, 2)
# card (42333, 1)
# resp (42333, 1)

# %%
unique, counts = np.unique(y_card, return_counts=True)
print("\ny_card label values and counts:\n",str(np.asarray((unique, counts)).T))
class_names_y_card = ['Normal','Abnormal'] # matches _90_10 processed files

unique, counts = np.unique(y_resp, return_counts=True)
print("\ny_resp label values and counts:\n",str(np.asarray((unique, counts)).T))
class_names_y_resp = ['Normal','Apnea','Hypopnea'] # matches _90_10 processed files
# Out:
# y_card label values and counts:
#  [[    0 37157]
#  [    1  5176]]
#
# y_resp label values and counts:
#  [[    0 23252]
#  [    1 15479]
#  [    2  3602]]

# %%
# topology and good article here
# https://blog.goodaudience.com/introduction-to-1d-convolutional-neural-networks-in-keras-for-time-sequences-3a7ff801a2cf
# ref for functional model https://keras.io/guides/functional_api/

# keeping all inputs for re-useability - model will decide which to use

def build_model(X_all_dict,y_all_dict):

    # input layers - 1st dim is timesteps, 2nd is features
    # this method give some configurability but lacks error checking.
    eeg_input = keras.Input(shape = (X_all_dict['eeg'].shape[1], X_all_dict['eeg'].shape[2]), name = "eeg")
    eog_input = keras.Input(shape = (X_all_dict['eog'].shape[1], X_all_dict['eog'].shape[2]), name = "eog")
    emg_input = keras.Input(shape = (X_all_dict['emg'].shape[1], X_all_dict['emg'].shape[2]), name = "emg")
    ecg_input = keras.Input(shape = (X_all_dict['ecg'].shape[1], X_all_dict['ecg'].shape[2]), name = "ecg")
    flow_input = keras.Input(shape = (X_all_dict['flow'].shape[1], X_all_dict['flow'].shape[2]), name = "flow")
    reff_input = keras.Input(shape = (X_all_dict['reff'].shape[1], X_all_dict['reff'].shape[2]), name = "reff")

    c = layers.Conv1D(filters=50, kernel_size=17, activation='relu')(flow_input)
    c = layers.SpatialDropout1D(0.25)(c)
    c = layers.Conv1D(filters=50, kernel_size=17, activation='relu')(c)
    c = layers.MaxPooling1D(pool_size=12)(c)
    c = layers.Dropout(0.25)(c)

    d = layers.Conv1D(filters=50, kernel_size=33, activation='relu')(reff_input)
    d = layers.SpatialDropout1D(0.25)(d)
    d = layers.Conv1D(filters=50, kernel_size=33, activation='relu')(d)
    d = layers.MaxPooling1D(pool_size=12)(d)
    d = layers.Dropout(0.25)(d)

    merged = layers.Concatenate(axis=1)([c, d]) 
    merged = layers.GlobalAveragePooling1D()(merged)
    #n_outputs = y_resp.shape[1] 
    n_outputs = 3 # just to test other items - need one-hot in model
    pred = layers.Dense(n_outputs, activation='softmax', name='act_pred')(merged)

    model = keras.Model([eeg_input, eog_input, emg_input, ecg_input, flow_input, reff_input],
                        pred)
    return model
if interactive:
    my_model = build_model(X_all_dict, y_all_dict)
    # model.summary()
    # pass rankdir="LR" to plot_model to display sideways
    display(keras.utils.plot_model(my_model, "my_model.png", show_shapes=True, rankdir = "LR"))

# %% [markdown]
# # Note I put the number of epochs way down to test the output and cross valid.

# %%
def train_model(model, X_train_dict, y_train_resp, X_valid_dict, y_valid_resp,
                BATCH_SIZE = 64, #
                NUM_EPOCHS = 3): # Max number run unless earlystopping callback fires

    callback = EarlyStopping(monitor='val_loss', mode = 'min', patience=10)
    model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

    sample_weights = compute_sample_weight('balanced', y_train_resp)
    sample_weights = np.sqrt(sample_weights) # no idea why weights are squared.
    #print("sample_weights",sample_weights)
    unique, counts = np.unique(sample_weights, return_counts=True)
    #print("sample_weights values and counts:\n",str(np.asarray((unique, counts)).T))
    
    history = model.fit(
        #{"acc": x_train_acc, "bvp": x_train_bvp, "eda": x_train_eda,"ptemp": x_train_ptemp},
        #{"act_pred": y_train},
        {"eeg": X_train_dict['eeg'], "eog": X_train_dict['eog'], "emg": X_train_dict['emg'],
         "ecg": X_train_dict['ecg'], "flow": X_train_dict['flow'], "reff":X_train_dict['reff']},
         {"act_pred": y_train_resp},
         #{"y_card":y_train_card, "y_resp":y_train_resp},
        batch_size = BATCH_SIZE,
        epochs=NUM_EPOCHS,
        callbacks=[callback],
        sample_weight=sample_weights,
        validation_data=({"eeg": X_valid_dict['eeg'], "eog": X_valid_dict['eog'], 
                          "emg": X_valid_dict['emg'], "ecg": X_valid_dict['ecg'],
                          "flow": X_valid_dict['flow'], "reff":X_valid_dict['reff']},
                         {"act_pred": y_valid_resp}),             
        verbose = 1) #0 = silent, 1 = progress bar, 2 = one line per epoch
    return history, model

# if (interactive):
#     # Note:  if you rerun this cell it continues to train the existing model
#     history, model = train_4input_CNN_no_val(model, x_train_acc, x_train_bvp,
#                                       x_train_eda, x_train_ptemp ,y_train,NUM_EPOCHS = 100)
#     #show final training loss
#     print("4 x 1D CNN Functional Model")
#     plt.plot(history.history["loss"], label="Training Loss")
#     plt.ylim([0,2.5]) #set limit - 1.2 has been a good value experimentally
#     plt.legend()
#     plt.show()

# %%
# Define per-fold score containers
acc_per_fold = []
loss_per_fold = []
y_pred_per_fold = []
y_valid_per_fold = []

skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)

start_time = time.time()

for i, (train_index, valid_index) in enumerate(skf.split(X, y[:,0], groups=sub)):
        print(f"Fold {i}:")
        #print(len(train_index), train_index)
        #print(len(valid_index), valid_index)

        # More complicated with dictionary of multiple inputs.
        # iterate through all keys and add the proper index array

        X_train_dict = {}
        X_valid_dict = {}
        y_train_dict = {}
        y_valid_dict = {}

        for key,item in X_all_dict.items():
            X_train_dict[key] = item[train_index]
            X_valid_dict[key] = item[valid_index]
        for key,item in y_all_dict.items():
            y_train_dict[key] = item[train_index]
            y_valid_dict[key] = item[valid_index]
        
        # for key,item in X_train_dict.items():
        #     print(key,item.shape)
        # for key,item in y_train_dict.items():
        #     print(key,item.shape)
        # for key,item in X_valid_dict.items():
        #     print(key,item.shape)
        # for key,item in y_valid_dict.items():
        #     print(key,item.shape)

        # TODO:  Move one-hot into model
        enc = OneHotEncoder(handle_unknown = 'ignore', sparse=False)
        y_train_card = enc.fit_transform(y_train_dict['card'])
        y_valid_card = enc.transform(y_valid_dict['card'])

        y_train_resp = enc.fit_transform(y_train_dict['resp'])
        y_valid_resp = enc.transform(y_valid_dict['resp'])

        # print(y_train_resp.shape)
        # print(y_valid_resp.shape)

        my_model = build_model(X_train_dict, y_train_dict)
        history, model = train_model(my_model, X_train_dict, y_train_resp, X_valid_dict, y_valid_resp)

        val_acc = history.history['val_accuracy'][-1]
        val_loss = history.history['val_loss'][-1] 

        acc_per_fold.append(val_acc * 100)
        loss_per_fold.append(val_loss)
                
        # Generate predictions
        y_pred = model.predict(X_valid_dict)

        y_pred = np.argmax(y_pred, axis=1)
        y_pred_per_fold.append(y_pred)
        y_valid_per_fold.append(np.argmax(y_valid_card, axis=1))

        # Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')
        plt.show()

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
#     print('------------------------------------------------------------------------')
    print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:4.2} - Accuracy: {acc_per_fold[i]:4.2f}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold):4.2f} (+- {np.std(acc_per_fold):5.4})')
acc_str = temp = str(f'> Accuracy: {np.mean(acc_per_fold):4.2f} (+- {np.std(acc_per_fold):5.4})')
print('------------------------------------------------------------------------')

# Show total training time
end_time = time.time()
train_time = timedelta(seconds=(end_time - start_time))
print('Total Training time =',(str(train_time).split(".")[0]), 'HH:MM:SS')
# to plot confusion matrices return concat versions of y
y_pred = np.concatenate(y_pred_per_fold)
y_test = np.concatenate(y_valid_per_fold)
#return acc_str, y_pred, y_test
# Out:
# Fold 0:
# Epoch 1/3
# 542/542 [==============================] - 7s 11ms/step - loss: 0.7060 - accuracy: 0.7429 - val_loss: 0.7296 - val_accuracy: 0.7310
# Epoch 2/3
# 542/542 [==============================] - 5s 9ms/step - loss: 0.6370 - accuracy: 0.7710 - val_loss: 0.7740 - val_accuracy: 0.7140
# Epoch 3/3
# 542/542 [==============================] - 5s 10ms/step - loss: 0.6186 - accuracy: 0.7719 - val_loss: 0.6836 - val_accuracy: 0.7374
# 241/241 [==============================] - 1s 2ms/step
# Fold 1:
# Epoch 1/3
# 523/523 [==============================] - 6s 11ms/step - loss: 0.7189 - accuracy: 0.7402 - val_loss: 0.6567 - val_accuracy: 0.7349
# Epoch 2/3
# 523/523 [==============================] - 5s 9ms/step - loss: 0.6551 - accuracy: 0.7658 - val_loss: 0.6338 - val_accuracy: 0.7375
# Epoch 3/3
# 523/523 [==============================] - 6s 11ms/step - loss: 0.6370 - accuracy: 0.7652 - val_loss: 0.5844 - val_accuracy: 0.7713
# 278/278 [==============================] - 1s 3ms/step
# Fold 2:
# Epoch 1/3
# 533/533 [==============================] - 6s 11ms/step - loss: 0.7072 - accuracy: 0.7384 - val_loss: 0.6933 - val_accuracy: 0.7400
# Epoch 2/3
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6462 - accuracy: 0.7633 - val_loss: 0.6362 - val_accuracy: 0.7632
# Epoch 3/3
# 533/533 [==============================] - 5s 10ms/step - loss: 0.6269 - accuracy: 0.7673 - val_loss: 0.6223 - val_accuracy: 0.7747
# 258/258 [==============================] - 1s 3ms/step
# Fold 3:
# Epoch 1/3
# 538/538 [==============================] - 6s 10ms/step - loss: 0.7314 - accuracy: 0.7269 - val_loss: 0.5706 - val_accuracy: 0.8150
# Epoch 2/3
# 538/538 [==============================] - 5s 10ms/step - loss: 0.6659 - accuracy: 0.7553 - val_loss: 0.5566 - val_accuracy: 0.8091
# Epoch 3/3
# 538/538 [==============================] - 5s 10ms/step - loss: 0.6488 - accuracy: 0.7608 - val_loss: 0.5477 - val_accuracy: 0.8109
# 249/249 [==============================] - 1s 2ms/step
# Fold 4:
# Epoch 1/3
# 512/512 [==============================] - 6s 11ms/step - loss: 0.7205 - accuracy: 0.7296 - val_loss: 0.7531 - val_accuracy: 0.7498
# Epoch 2/3
# 512/512 [==============================] - 5s 9ms/step - loss: 0.6593 - accuracy: 0.7579 - val_loss: 0.6904 - val_accuracy: 0.8025
# Epoch 3/3
# 512/512 [==============================] - 5s 10ms/step - loss: 0.6382 - accuracy: 0.7651 - val_loss: 0.6288 - val_accuracy: 0.7952
# 300/300 [==============================] - 1s 2ms/step
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss: 0.68 - Accuracy: 73.74%
# > Fold 2 - Loss: 0.58 - Accuracy: 77.13%
# > Fold 3 - Loss: 0.62 - Accuracy: 77.47%
# > Fold 4 - Loss: 0.55 - Accuracy: 81.09%
# > Fold 5 - Loss: 0.63 - Accuracy: 79.52%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 77.79 (+- 2.482)
# ------------------------------------------------------------------------
# Total Training time = 0:02:17 HH:MM:SS

# %%
y_valid_resp.shape
# Out:
# (7681, 3)

# %%
y_pred = model.predict(X_valid_dict)
# Out:
# 241/241 [==============================] - 1s 4ms/step

# %%
enc = OneHotEncoder(handle_unknown = 'ignore', sparse=False)
y_train_card = enc.fit_transform(y_train_dict['card'])
y_valid_card = enc.transform(y_valid_dict['card'])

y_train_resp = enc.fit_transform(y_train_dict['resp'])
y_valid_resp = enc.transform(y_valid_dict['resp'])

print(y_train_resp.shape)
print(y_valid_resp.shape)
# Out:
# (32755, 3)
# (9578, 3)

# %%
my_model = build_model(X_train_dict, y_train_dict)

# %%
history, model = train_model(my_model, X_train_dict, y_train_resp, X_valid_dict, y_valid_resp)
# Out:
# sample_weights [0.63143805 0.63143805 0.63143805 ... 0.91030042 0.91030042 0.63143805]
# sample_weights values and counts:
#  [[6.31438054e-01 1.77960000e+04]
#  [9.10300424e-01 1.19240000e+04]
#  [2.15519080e+00 3.03500000e+03]]
# Epoch 1/30
# 1024/1024 [==============================] - 249s 243ms/step - loss: 0.6432 - accuracy: 0.7580 - val_loss: 0.6128 - val_accuracy: 0.8104
# Epoch 2/30
# 1024/1024 [==============================] - 246s 240ms/step - loss: 0.5939 - accuracy: 0.7817 - val_loss: 0.5858 - val_accuracy: 0.8151
# Epoch 3/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5789 - accuracy: 0.7840 - val_loss: 0.5586 - val_accuracy: 0.8188
# Epoch 4/30
# 1024/1024 [==============================] - 246s 240ms/step - loss: 0.5671 - accuracy: 0.7895 - val_loss: 0.5125 - val_accuracy: 0.8252
# Epoch 5/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5593 - accuracy: 0.7918 - val_loss: 0.5080 - val_accuracy: 0.8270
# Epoch 6/30
# 1024/1024 [==============================] - 244s 238ms/step - loss: 0.5589 - accuracy: 0.7933 - val_loss: 0.5389 - val_accuracy: 0.8225
# Epoch 7/30
# 1024/1024 [==============================] - 244s 239ms/step - loss: 0.5530 - accuracy: 0.7940 - val_loss: 0.5058 - val_accuracy: 0.8309
# Epoch 8/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5491 - accuracy: 0.7942 - val_loss: 0.4973 - val_accuracy: 0.8287
# Epoch 9/30
# 1024/1024 [==============================] - 246s 240ms/step - loss: 0.5475 - accuracy: 0.7957 - val_loss: 0.5129 - val_accuracy: 0.8234
# Epoch 10/30
# 1024/1024 [==============================] - 243s 238ms/step - loss: 0.5442 - accuracy: 0.7953 - val_loss: 0.4983 - val_accuracy: 0.8293
# Epoch 11/30
# 1024/1024 [==============================] - 244s 238ms/step - loss: 0.5440 - accuracy: 0.7962 - val_loss: 0.6183 - val_accuracy: 0.8297
# Epoch 12/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5401 - accuracy: 0.7976 - val_loss: 0.5172 - val_accuracy: 0.8232
# Epoch 13/30
# 1024/1024 [==============================] - 246s 240ms/step - loss: 0.5391 - accuracy: 0.7998 - val_loss: 0.4967 - val_accuracy: 0.8323
# Epoch 14/30
# 1024/1024 [==============================] - 244s 238ms/step - loss: 0.5370 - accuracy: 0.7984 - val_loss: 0.4794 - val_accuracy: 0.8387
# Epoch 15/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5354 - accuracy: 0.7999 - val_loss: 0.4899 - val_accuracy: 0.8347
# Epoch 16/30
# 1024/1024 [==============================] - 244s 238ms/step - loss: 0.5354 - accuracy: 0.7995 - val_loss: 0.4861 - val_accuracy: 0.8379
# Epoch 17/30
# 1024/1024 [==============================] - 243s 237ms/step - loss: 0.5364 - accuracy: 0.7995 - val_loss: 0.4783 - val_accuracy: 0.8404
# Epoch 18/30
# 1024/1024 [==============================] - 242s 236ms/step - loss: 0.5325 - accuracy: 0.7997 - val_loss: 0.4792 - val_accuracy: 0.8398
# Epoch 19/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5319 - accuracy: 0.7995 - val_loss: 0.4776 - val_accuracy: 0.8363
# Epoch 20/30
# 1024/1024 [==============================] - 247s 241ms/step - loss: 0.5304 - accuracy: 0.8006 - val_loss: 0.4833 - val_accuracy: 0.8413
# Epoch 21/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5284 - accuracy: 0.8016 - val_loss: 0.4906 - val_accuracy: 0.8378
# Epoch 22/30
# 1024/1024 [==============================] - 244s 238ms/step - loss: 0.5261 - accuracy: 0.8031 - val_loss: 0.5292 - val_accuracy: 0.8361
# Epoch 23/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5265 - accuracy: 0.8022 - val_loss: 0.4822 - val_accuracy: 0.8388
# Epoch 24/30
# 1024/1024 [==============================] - 245s 240ms/step - loss: 0.5286 - accuracy: 0.8013 - val_loss: 0.4687 - val_accuracy: 0.8397
# Epoch 25/30
# 1024/1024 [==============================] - 244s 238ms/step - loss: 0.5253 - accuracy: 0.8025 - val_loss: 0.4785 - val_accuracy: 0.8374
# Epoch 26/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5223 - accuracy: 0.8044 - val_loss: 0.4941 - val_accuracy: 0.8374
# Epoch 27/30
# 1024/1024 [==============================] - 246s 240ms/step - loss: 0.5230 - accuracy: 0.8027 - val_loss: 0.4826 - val_accuracy: 0.8336
# Epoch 28/30
# 1024/1024 [==============================] - 244s 239ms/step - loss: 0.5215 - accuracy: 0.8040 - val_loss: 0.4799 - val_accuracy: 0.8361
# Epoch 29/30
# 1024/1024 [==============================] - 243s 238ms/step - loss: 0.5193 - accuracy: 0.8031 - val_loss: 0.4948 - val_accuracy: 0.8376
# Epoch 30/30
# 1024/1024 [==============================] - 245s 239ms/step - loss: 0.5236 - accuracy: 0.8031 - val_loss: 0.4871 - val_accuracy: 0.8388

# %% [markdown]
# ## Run a stratified 5-fold group-based cross validation

# %%
def run_cross_val():
    """runs a five fold cross-validation pass. returns accuracy string"""
    #print ("running model",my_model.description)

    # Define per-fold score containers
    acc_per_fold = []
    loss_per_fold = []
    y_pred_per_fold = []
    y_test_per_fold = []

    skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)

    start_time = time.time()

    for i, (train_index, test_index) in enumerate(skf.split(X, y[:,0], groups=sub)):
        print(f"Fold {i}:")

        # x_train, y_train = X[train_index], y[train_index]
        # x_test, y_test = X[test_index], y[test_index]
        # x_train_eeg, x_train_eog, x_train_emg, x_train_ecg, x_train_flow,x_train_reff \
        #     = X_eeg[train_index], X_eog[train_index], X_emg[train_index], X_ecg[train_index], X_flow[train_index], X_reff[train_index]
        # y_train_card, y_train_resp = y_card[train_index], y_resp[train_index]

        # x_test_eeg, x_test_eog, x_test_emg, x_test_ecg, x_test_flow,x_test_reff \
        #     = X_eeg[test_index], X_eog[test_index], X_emg[test_index], X_ecg[test_index], X_flow[test_index], X_reff[test_index]
        # y_test_card, y_test_resp = y_card[test_index], y_resp[test_index]
        # One Hot Encode: Note for respiratory there are 5 relatively frequent
        # categories but others can appear in only a portion of the folds.

        enc = OneHotEncoder(handle_unknown = 'ignore', sparse=False)
        y_train_card = enc.fit_transform(y_train_card)
        y_test_card = enc.transform(y_test_card)

        y_train_resp = enc.fit_transform(y_train_resp)
        y_test_resp = enc.transform(y_test_resp)

        model = build_model(x_train_eeg, x_train_eog, x_train_emg, x_train_ecg,
                            x_train_flow, x_train_reff, y_train_resp)
        history, model = train_model(model, 
                                     x_train_eeg, x_train_eog, x_train_emg, x_train_ecg,
                                     x_train_flow, x_train_reff, y_train_resp,
                                     x_test_eeg, x_test_eog, x_test_emg, x_test_ecg,
                                     x_test_flow, x_test_reff, y_test_resp)  
        val_acc = history.history['val_accuracy'][-1]
        val_loss = history.history['val_loss'][-1] 

        acc_per_fold.append(val_acc * 100)
        loss_per_fold.append(val_loss)

        # Generate predictions
        y_pred = model.predict([x_test_eeg, x_test_eog, x_test_emg, x_test_ecg,
                               x_test_flow, x_test_reff])

        y_pred = np.argmax(y_pred, axis=1)
        y_pred_per_fold.append(y_pred)
        y_test_per_fold.append(np.argmax(y_test_card, axis=1))

        # Plot training & validation loss values
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')
        plt.show()

    # == Provide average scores ==
    print('------------------------------------------------------------------------')
    print('Score per fold')
    for i in range(0, len(acc_per_fold)):
    #     print('------------------------------------------------------------------------')
        print(f'> Fold {i+1} - Loss: {loss_per_fold[i]:4.2} - Accuracy: {acc_per_fold[i]:4.2f}%')
    print('------------------------------------------------------------------------')
    print('Average scores for all folds:')
    print(f'> Accuracy: {np.mean(acc_per_fold):4.2f} (+- {np.std(acc_per_fold):5.4})')
    acc_str = temp = str(f'> Accuracy: {np.mean(acc_per_fold):4.2f} (+- {np.std(acc_per_fold):5.4})')
    print('------------------------------------------------------------------------')

    # Show total training time
    end_time = time.time()
    train_time = timedelta(seconds=(end_time - start_time))
    print('Total Training time =',(str(train_time).split(".")[0]), 'HH:MM:SS')
    # to plot confusion matrices return concat versions of y
    y_pred = np.concatenate(y_pred_per_fold)
    y_test = np.concatenate(y_test_per_fold)
    return acc_str, y_pred, y_test
result, y_pred, y_test = run_cross_val()
#print ("running model",my_model.description)
print(result)
# Out:
# Fold 0:
# sample_weights [0.63394696 0.63394696 0.88530229 ... 0.88530229 0.88530229 0.63394696]
# sample_weights values and counts:
#  [[6.33946962e-01 1.88190000e+04]
#  [8.85302291e-01 1.31220000e+04]
#  [2.37235177e+00 2.71100000e+03]]
# Epoch 1/30
# 1083/1083 [==============================] - 9s 8ms/step - loss: 0.6894 - accuracy: 0.7456 - val_loss: 0.7372 - val_accuracy: 0.7321
# Epoch 2/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.6425 - accuracy: 0.7665 - val_loss: 0.7167 - val_accuracy: 0.7336
# Epoch 3/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.6220 - accuracy: 0.7779 - val_loss: 0.6815 - val_accuracy: 0.7358
# Epoch 4/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.6047 - accuracy: 0.7747 - val_loss: 0.7091 - val_accuracy: 0.7219
# Epoch 5/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5983 - accuracy: 0.7743 - val_loss: 0.7141 - val_accuracy: 0.7194
# Epoch 6/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5936 - accuracy: 0.7785 - val_loss: 0.6956 - val_accuracy: 0.7227
# Epoch 7/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5898 - accuracy: 0.7778 - val_loss: 0.6774 - val_accuracy: 0.7341
# Epoch 8/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5839 - accuracy: 0.7781 - val_loss: 0.6849 - val_accuracy: 0.7203
# Epoch 9/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5791 - accuracy: 0.7765 - val_loss: 0.6680 - val_accuracy: 0.7237
# Epoch 10/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5768 - accuracy: 0.7763 - val_loss: 0.6723 - val_accuracy: 0.7310
# Epoch 11/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5793 - accuracy: 0.7766 - val_loss: 0.7307 - val_accuracy: 0.6898
# Epoch 12/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5748 - accuracy: 0.7790 - val_loss: 0.6589 - val_accuracy: 0.7332
# Epoch 13/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5730 - accuracy: 0.7766 - val_loss: 0.7210 - val_accuracy: 0.6924
# Epoch 14/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5697 - accuracy: 0.7764 - val_loss: 0.6715 - val_accuracy: 0.7295
# Epoch 15/30
# 1083/1083 [==============================] - 9s 8ms/step - loss: 0.5661 - accuracy: 0.7804 - val_loss: 0.6861 - val_accuracy: 0.7094
# Epoch 16/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5677 - accuracy: 0.7799 - val_loss: 0.6621 - val_accuracy: 0.7266
# Epoch 17/30
# 1083/1083 [==============================] - 8s 8ms/step - loss: 0.5661 - accuracy: 0.7791 - val_loss: 0.7086 - val_accuracy: 0.6946
# Epoch 18/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5640 - accuracy: 0.7765 - val_loss: 0.6550 - val_accuracy: 0.7305
# Epoch 19/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5628 - accuracy: 0.7798 - val_loss: 0.6688 - val_accuracy: 0.7153
# Epoch 20/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5619 - accuracy: 0.7802 - val_loss: 0.7205 - val_accuracy: 0.6724
# Epoch 21/30
# 1083/1083 [==============================] - 8s 8ms/step - loss: 0.5621 - accuracy: 0.7761 - val_loss: 0.6657 - val_accuracy: 0.7202
# Epoch 22/30
# 1083/1083 [==============================] - 7s 7ms/step - loss: 0.5608 - accuracy: 0.7813 - val_loss: 0.6999 - val_accuracy: 0.7072
# Epoch 23/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5601 - accuracy: 0.7804 - val_loss: 0.6929 - val_accuracy: 0.7037
# Epoch 24/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5562 - accuracy: 0.7837 - val_loss: 0.6914 - val_accuracy: 0.7049
# Epoch 25/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5573 - accuracy: 0.7840 - val_loss: 0.6627 - val_accuracy: 0.7215
# Epoch 26/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5578 - accuracy: 0.7817 - val_loss: 0.6612 - val_accuracy: 0.7248
# Epoch 27/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5533 - accuracy: 0.7817 - val_loss: 0.6669 - val_accuracy: 0.7201
# Epoch 28/30
# 1083/1083 [==============================] - 8s 7ms/step - loss: 0.5543 - accuracy: 0.7812 - val_loss: 0.7023 - val_accuracy: 0.7073
# 241/241 [==============================] - 1s 3ms/step
# Fold 1:
# sample_weights [0.61486862 0.61486862 0.93945713 ... 0.93945713 0.93945713 0.61486862]
# sample_weights values and counts:
#  [[6.14868622e-01 1.87180000e+04]
#  [9.39457128e-01 1.17910000e+04]
#  [2.23729665e+00 2.93000000e+03]]
# Epoch 1/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.7165 - accuracy: 0.7396 - val_loss: 0.6611 - val_accuracy: 0.7466
# Epoch 2/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6634 - accuracy: 0.7632 - val_loss: 0.6441 - val_accuracy: 0.7358
# Epoch 3/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6404 - accuracy: 0.7645 - val_loss: 0.6329 - val_accuracy: 0.7442
# Epoch 4/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6341 - accuracy: 0.7636 - val_loss: 0.6335 - val_accuracy: 0.7399
# Epoch 5/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.6249 - accuracy: 0.7659 - val_loss: 0.6060 - val_accuracy: 0.7588
# Epoch 6/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.6222 - accuracy: 0.7640 - val_loss: 0.6279 - val_accuracy: 0.7429
# Epoch 7/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6180 - accuracy: 0.7678 - val_loss: 0.6382 - val_accuracy: 0.7350
# Epoch 8/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6125 - accuracy: 0.7691 - val_loss: 0.6112 - val_accuracy: 0.7490
# Epoch 9/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6087 - accuracy: 0.7658 - val_loss: 0.6386 - val_accuracy: 0.7340
# Epoch 10/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.6061 - accuracy: 0.7682 - val_loss: 0.6061 - val_accuracy: 0.7412
# Epoch 11/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.6074 - accuracy: 0.7690 - val_loss: 0.5837 - val_accuracy: 0.7634
# Epoch 12/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.6038 - accuracy: 0.7687 - val_loss: 0.5858 - val_accuracy: 0.7613
# Epoch 13/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5996 - accuracy: 0.7695 - val_loss: 0.6168 - val_accuracy: 0.7376
# Epoch 14/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6026 - accuracy: 0.7670 - val_loss: 0.5915 - val_accuracy: 0.7677
# Epoch 15/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.6003 - accuracy: 0.7691 - val_loss: 0.6200 - val_accuracy: 0.7515
# Epoch 16/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5962 - accuracy: 0.7701 - val_loss: 0.5844 - val_accuracy: 0.7638
# Epoch 17/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5964 - accuracy: 0.7693 - val_loss: 0.6069 - val_accuracy: 0.7532
# Epoch 18/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5925 - accuracy: 0.7686 - val_loss: 0.6051 - val_accuracy: 0.7584
# Epoch 19/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5897 - accuracy: 0.7720 - val_loss: 0.5757 - val_accuracy: 0.7615
# Epoch 20/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5906 - accuracy: 0.7693 - val_loss: 0.5668 - val_accuracy: 0.7773
# Epoch 21/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5876 - accuracy: 0.7718 - val_loss: 0.5662 - val_accuracy: 0.7809
# Epoch 22/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5882 - accuracy: 0.7701 - val_loss: 0.6232 - val_accuracy: 0.7284
# Epoch 23/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5863 - accuracy: 0.7684 - val_loss: 0.5762 - val_accuracy: 0.7594
# Epoch 24/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5855 - accuracy: 0.7672 - val_loss: 0.5655 - val_accuracy: 0.7650
# Epoch 25/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5846 - accuracy: 0.7706 - val_loss: 0.5842 - val_accuracy: 0.7520
# Epoch 26/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5818 - accuracy: 0.7701 - val_loss: 0.5994 - val_accuracy: 0.7503
# Epoch 27/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5839 - accuracy: 0.7705 - val_loss: 0.6190 - val_accuracy: 0.7291
# Epoch 28/30
# 1045/1045 [==============================] - 8s 7ms/step - loss: 0.5809 - accuracy: 0.7684 - val_loss: 0.6005 - val_accuracy: 0.7676
# Epoch 29/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5818 - accuracy: 0.7725 - val_loss: 0.5475 - val_accuracy: 0.7811
# Epoch 30/30
# 1045/1045 [==============================] - 7s 7ms/step - loss: 0.5787 - accuracy: 0.7709 - val_loss: 0.5635 - val_accuracy: 0.7629
# 278/278 [==============================] - 1s 3ms/step
# Fold 2:
# sample_weights [0.61842975 0.61842975 0.92421043 ... 2.30678398 0.61842975 2.30678398]
# sample_weights values and counts:
#  [[6.18429748e-01 1.89870000e+04]
#  [9.24210432e-01 1.22780000e+04]
#  [2.30678398e+00 2.82500000e+03]]
# Epoch 1/30
# 1066/1066 [==============================] - 9s 8ms/step - loss: 0.7028 - accuracy: 0.7363 - val_loss: 0.6690 - val_accuracy: 0.7535
# Epoch 2/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.6524 - accuracy: 0.7560 - val_loss: 0.6572 - val_accuracy: 0.7517
# Epoch 3/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.6344 - accuracy: 0.7619 - val_loss: 0.6459 - val_accuracy: 0.7735
# Epoch 4/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.6230 - accuracy: 0.7630 - val_loss: 0.6353 - val_accuracy: 0.7668
# Epoch 5/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.6194 - accuracy: 0.7655 - val_loss: 0.6473 - val_accuracy: 0.7467
# Epoch 6/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.6112 - accuracy: 0.7641 - val_loss: 0.6188 - val_accuracy: 0.7600
# Epoch 7/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.6053 - accuracy: 0.7687 - val_loss: 0.6073 - val_accuracy: 0.7725
# Epoch 8/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.6032 - accuracy: 0.7658 - val_loss: 0.6169 - val_accuracy: 0.7677
# Epoch 9/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.6006 - accuracy: 0.7668 - val_loss: 0.6028 - val_accuracy: 0.7774
# Epoch 10/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.5987 - accuracy: 0.7679 - val_loss: 0.6316 - val_accuracy: 0.7610
# Epoch 11/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.5962 - accuracy: 0.7681 - val_loss: 0.5934 - val_accuracy: 0.7744
# Epoch 12/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.5927 - accuracy: 0.7686 - val_loss: 0.6430 - val_accuracy: 0.7441
# Epoch 13/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.5900 - accuracy: 0.7662 - val_loss: 0.6227 - val_accuracy: 0.7531
# Epoch 14/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.5893 - accuracy: 0.7673 - val_loss: 0.6256 - val_accuracy: 0.7671
# Epoch 15/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.5902 - accuracy: 0.7691 - val_loss: 0.6326 - val_accuracy: 0.7462
# Epoch 16/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.5873 - accuracy: 0.7671 - val_loss: 0.6204 - val_accuracy: 0.7632
# Epoch 17/30
# 1066/1066 [==============================] - 9s 8ms/step - loss: 0.5846 - accuracy: 0.7675 - val_loss: 0.5965 - val_accuracy: 0.7699
# Epoch 18/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.5808 - accuracy: 0.7685 - val_loss: 0.6227 - val_accuracy: 0.7469
# Epoch 19/30
# 1066/1066 [==============================] - 8s 7ms/step - loss: 0.5825 - accuracy: 0.7696 - val_loss: 0.6347 - val_accuracy: 0.7350
# Epoch 20/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.5825 - accuracy: 0.7663 - val_loss: 0.6190 - val_accuracy: 0.7492
# Epoch 21/30
# 1066/1066 [==============================] - 7s 7ms/step - loss: 0.5788 - accuracy: 0.7708 - val_loss: 0.6112 - val_accuracy: 0.7719
# 258/258 [==============================] - 1s 2ms/step
# Fold 3:
# sample_weights [0.63267324 0.63267324 0.89630349 ... 0.89630349 0.89630349 0.63267324]
# sample_weights values and counts:
#  [[6.32673240e-01 1.86880000e+04]
#  [8.96303490e-01 1.28010000e+04]
#  [2.27121031e+00 2.90700000e+03]]
# Epoch 1/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.7226 - accuracy: 0.7338 - val_loss: 0.5900 - val_accuracy: 0.8089
# Epoch 2/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.6644 - accuracy: 0.7594 - val_loss: 0.5701 - val_accuracy: 0.8053
# Epoch 3/30
# 1075/1075 [==============================] - 8s 8ms/step - loss: 0.6485 - accuracy: 0.7589 - val_loss: 0.5513 - val_accuracy: 0.8058
# Epoch 4/30
# 1075/1075 [==============================] - 8s 8ms/step - loss: 0.6393 - accuracy: 0.7615 - val_loss: 0.5276 - val_accuracy: 0.8140
# Epoch 5/30
# 1075/1075 [==============================] - 8s 8ms/step - loss: 0.6312 - accuracy: 0.7625 - val_loss: 0.5560 - val_accuracy: 0.7988
# Epoch 6/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.6250 - accuracy: 0.7623 - val_loss: 0.5433 - val_accuracy: 0.8057
# Epoch 7/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.6240 - accuracy: 0.7600 - val_loss: 0.5206 - val_accuracy: 0.8121
# Epoch 8/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6173 - accuracy: 0.7620 - val_loss: 0.5325 - val_accuracy: 0.8104
# Epoch 9/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.6156 - accuracy: 0.7620 - val_loss: 0.6037 - val_accuracy: 0.7703
# Epoch 10/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6133 - accuracy: 0.7633 - val_loss: 0.5371 - val_accuracy: 0.8077
# Epoch 11/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6098 - accuracy: 0.7635 - val_loss: 0.5415 - val_accuracy: 0.8085
# Epoch 12/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.6079 - accuracy: 0.7631 - val_loss: 0.5322 - val_accuracy: 0.8118
# Epoch 13/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.6049 - accuracy: 0.7648 - val_loss: 0.5617 - val_accuracy: 0.7934
# Epoch 14/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6051 - accuracy: 0.7641 - val_loss: 0.5462 - val_accuracy: 0.8033
# Epoch 15/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6004 - accuracy: 0.7651 - val_loss: 0.5195 - val_accuracy: 0.8105
# Epoch 16/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6026 - accuracy: 0.7638 - val_loss: 0.5483 - val_accuracy: 0.7998
# Epoch 17/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.5991 - accuracy: 0.7669 - val_loss: 0.5304 - val_accuracy: 0.7998
# Epoch 18/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6004 - accuracy: 0.7631 - val_loss: 0.5140 - val_accuracy: 0.8113
# Epoch 19/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.6004 - accuracy: 0.7669 - val_loss: 0.5070 - val_accuracy: 0.8095
# Epoch 20/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.5974 - accuracy: 0.7691 - val_loss: 0.5369 - val_accuracy: 0.8050
# Epoch 21/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.5944 - accuracy: 0.7659 - val_loss: 0.5118 - val_accuracy: 0.8148
# Epoch 22/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.5919 - accuracy: 0.7705 - val_loss: 0.5382 - val_accuracy: 0.7922
# Epoch 23/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.5909 - accuracy: 0.7683 - val_loss: 0.5250 - val_accuracy: 0.8095
# Epoch 24/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.5911 - accuracy: 0.7668 - val_loss: 0.5495 - val_accuracy: 0.7906
# Epoch 25/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.5924 - accuracy: 0.7676 - val_loss: 0.5614 - val_accuracy: 0.7891
# Epoch 26/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.5897 - accuracy: 0.7692 - val_loss: 0.5149 - val_accuracy: 0.8061
# Epoch 27/30
# 1075/1075 [==============================] - 7s 7ms/step - loss: 0.5894 - accuracy: 0.7694 - val_loss: 0.5272 - val_accuracy: 0.8050
# Epoch 28/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.5899 - accuracy: 0.7700 - val_loss: 0.5213 - val_accuracy: 0.8046
# Epoch 29/30
# 1075/1075 [==============================] - 8s 7ms/step - loss: 0.5926 - accuracy: 0.7678 - val_loss: 0.5372 - val_accuracy: 0.7998
# 249/249 [==============================] - 1s 2ms/step
# Fold 4:
# sample_weights [0.63143805 0.63143805 0.63143805 ... 0.91030042 0.91030042 0.63143805]
# sample_weights values and counts:
#  [[6.31438054e-01 1.77960000e+04]
#  [9.10300424e-01 1.19240000e+04]
#  [2.15519080e+00 3.03500000e+03]]
# Epoch 1/30
# 1024/1024 [==============================] - 9s 8ms/step - loss: 0.7181 - accuracy: 0.7295 - val_loss: 0.7497 - val_accuracy: 0.7697
# Epoch 2/30
# 1024/1024 [==============================] - 8s 7ms/step - loss: 0.6512 - accuracy: 0.7614 - val_loss: 0.7154 - val_accuracy: 0.7700
# Epoch 3/30
# 1024/1024 [==============================] - 8s 7ms/step - loss: 0.6386 - accuracy: 0.7631 - val_loss: 0.5961 - val_accuracy: 0.8017
# Epoch 4/30
# 1024/1024 [==============================] - 8s 7ms/step - loss: 0.6332 - accuracy: 0.7597 - val_loss: 0.6042 - val_accuracy: 0.8016
# Epoch 5/30
# 1024/1024 [==============================] - 8s 7ms/step - loss: 0.6256 - accuracy: 0.7605 - val_loss: 0.6551 - val_accuracy: 0.7727
# Epoch 6/30
# 1024/1024 [==============================] - 8s 7ms/step - loss: 0.6213 - accuracy: 0.7591 - val_loss: 0.7177 - val_accuracy: 0.7714
# Epoch 7/30
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.6219 - accuracy: 0.7590 - val_loss: 0.6383 - val_accuracy: 0.7787
# Epoch 8/30
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.6186 - accuracy: 0.7612 - val_loss: 0.6517 - val_accuracy: 0.7721
# Epoch 9/30
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.6143 - accuracy: 0.7598 - val_loss: 0.6794 - val_accuracy: 0.7682
# Epoch 10/30
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.6137 - accuracy: 0.7589 - val_loss: 0.6062 - val_accuracy: 0.7747
# Epoch 11/30
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.6098 - accuracy: 0.7593 - val_loss: 0.6690 - val_accuracy: 0.7786
# Epoch 12/30
# 1024/1024 [==============================] - 7s 7ms/step - loss: 0.6071 - accuracy: 0.7590 - val_loss: 0.6632 - val_accuracy: 0.7493
# Epoch 13/30
# 1024/1024 [==============================] - 8s 8ms/step - loss: 0.6020 - accuracy: 0.7593 - val_loss: 0.6558 - val_accuracy: 0.7695
# 300/300 [==============================] - 1s 3ms/step
# ------------------------------------------------------------------------
# Score per fold
# > Fold 1 - Loss:  0.7 - Accuracy: 70.73%
# > Fold 2 - Loss: 0.56 - Accuracy: 76.29%
# > Fold 3 - Loss: 0.61 - Accuracy: 77.19%
# > Fold 4 - Loss: 0.54 - Accuracy: 79.98%
# > Fold 5 - Loss: 0.66 - Accuracy: 76.95%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 76.23 (+- 3.024)
# ------------------------------------------------------------------------
# Total Training time = 0:18:13 HH:MM:SS
# > Accuracy: 76.23 (+- 3.024)

# %%
# == Confusion matrix ==
from sklearn.metrics import confusion_matrix
import itertools

#moved to evaluate function
#y_pred = np.concatenate(y_pred_per_fold)
#y_test = np.concatenate(y_test_per_fold)

# print(classification_report(y_test, y_pred, target_names=class_names))
print(classification_report(y_valid, y_pred))

cm = confusion_matrix(y_valid, y_pred)

def plot_confusion_matrix(cm, classes,
                            normalize=True,
                            title='Confusion matrix',
                            cmap=plt.cm.Blues):
        """
        This function prints and plots the confusion matrix.
        Normalization can be applied by setting `normalize=True`.
        """
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
            print("Normalized confusion matrix")
            print(np.array(cm).round(2)) # to limit digits
        else:
            print('Confusion matrix, without normalization')
            print(cm)
    
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes,rotation=90)
        plt.yticks(tick_marks, classes)
    
        fmt = '.2f' if normalize else 'd'
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    
        plt.tight_layout()
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
title = 'PSG-Audio Group 5-fold\n'
#title += "Predicting " + labels + " using " + ch_group + '\n'
title += 'Accuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred))+'\n'
class_names = ['C0','C1','C2'] # placeholder for now
plot_confusion_matrix(cm, classes=class_names, title=title, cmap='cubehelix_r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-bd7b3d4ede4e> in <module>
#       8
#       9 # print(classification_report(y_test, y_pred, target_names=class_names))
# ---> 10 print(classification_report(y_valid, y_pred))
#      11
#      12 cm = confusion_matrix(y_valid, y_pred)
#
# NameError: name 'y_valid' is not defined

# %% [markdown]
# # STOP - the following code is to load the data from and save figures to google drive.
# You are welcome to use it, but it is untested outside of my environment.

# %%
def get_load_data_utils():
    """checks for local file, if none downloads from IMICS repository.
    Assumes a global my_dir has been defined (default is my_dir = ".")
    :return: nothing"""
    fname = 'load_data_utils.py'
    ffname = os.path.join(my_dir,fname)
    if (os.path.exists(ffname)):
        print ("Local load_data_utils.py found, skipping download")
    else:
        print("Downloading",fname, "from IMICS git repo")
        urllib.request.urlretrieve("https://raw.githubusercontent.com/imics-lab/load_data_time_series/main/load_data_utils.py", filename=fname)
if interactive:
    get_load_data_utils()
# Out:
# Downloading load_data_utils.py from IMICS git repo

# %%
from load_data_utils import get_env_info
from load_data_utils import get_log_ffname
from load_data_utils import tabulate_numpy_arrays
from load_data_utils import channel_powerset
if interactive:
    print('My env_info: \n' + get_env_info())
# Out:
# My env_info:
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# GPU: name, driver_version, memory.total [MiB]
# Tesla T4, 510.47.03, 15360 MiB

# %%
save_log = False # set to False to avoid a problem if accidentally run...
# alternate confusion matrix with fig object to save
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm,
                    index = class_names, 
                    columns = class_names)
fig = plt.figure(figsize=(6.5,5))
sns.heatmap(cm_df, annot=True, fmt='d', cmap='cubehelix_r')
#plt.title('Insert title here\n
#plt.title('Accuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.title('Accuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout() # keeps labels from being cutoff when saving as pdf
plt.show()
if save_log:
    log_ffname = get_log_ffname(
    log_file_dir = '/content/drive/My Drive/Colab_Run_Results',
    base_fname = "PSG_Multi_Output_Work")
    print("Saving results to", log_ffname)
    with open(log_ffname, "a") as file_object:
        file_object.write("Generated by Evaluate_Model_PSG-Audio.ipynb\n")
        file_object.write("Processed PSG with 5 fold via sklearn GroupKFold\n")
        file_object.write("Final Accuracy: %0.3f\n" %accuracy_score(y_test, y_pred))
        file_object.write("Classification Report\n")
        file_object.write(classification_report(y_test, y_pred, target_names=class_names))
        file_object.write("Confusion Matrix\n")
        file_object.write(str(cm))
    cm_ffname = log_ffname.split('.')[0] + '_cm.pdf'
    print("saving cm plot as",cm_ffname)
    fig.savefig(cm_ffname,format='pdf', dpi=1200)
    full_model_fname = log_ffname.split('.')[0] + '_model.txt'
    with open(full_model_fname, "a") as file_object:
        model.summary(print_fn=lambda x: file_object.write(x + '\n'))
        #acknowledgement https://stackoverflow.com/users/14951382/sparklingdew
    #plot using keras function
    #ref https://keras.io/api/utils/model_plotting_utils/
    full_mplot_fname = log_ffname.split('.')[0] + '_model.png'
    keras.utils.plot_model(model, to_file=full_mplot_fname, show_shapes=True)
